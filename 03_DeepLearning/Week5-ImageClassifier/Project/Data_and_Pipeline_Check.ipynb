# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2A: Get the Data](#step2a)
# - [Step 2B: Explore the Data](#step2b)
# - [Step 2C: Create Sample Data](#step2c)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#predictions)
# - [Step 6. Display Mistakes](#display)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 1: Data Understanding & Pipeline Check</font>
#
# Here, we will slightly modify the steps  we had used to train Neural Networks:
#
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data, and check the pipeline before training the full network
# - Step 5 - Train on full Data
# - Step 6 - Improve your model
#
#
# In this notebook we will detail the steps 1 to 4, and do some coding along the way! You will implement Steps 5 & 6 in the next notebook.
#
# This notebook contains  30 points. <font style="color:red">The sections in red are the ones that carry marks.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your Problem </font><a name="step1"></a>
#
# As you already know, Image Classification helps classify an image based on its visual content. So, the model is supposed to look at the given image and predict which object is present in it. Obviously, the number of objects which it can predict depends on how many you trained it on.
#
#
# In our problem, we want to classify an input image between **3 animals - Cat, Dog and Panda**.
#
# ### <font style="color:green">What Do We Need and How to Achieve It? </font>
#
# You need correctly-labelled images of each animal. Train a decent-sized network to , understand the input image.

# %% [markdown]
# # <font style="color:blue">Step 2A: Get the Data </font><a name="step2a"></a>
#
# Let’s use a dataset from kaggle. [**Check it out here**](https://www.kaggle.com/ashishsaxena2209/animal-image-datasetdog-cat-and-panda).
#
# It has separate folders for each animal, each consisting of `1000` images. We have split it into `80:20` ratio for `train:validation`. To download, [**click  here**](https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1).

# %%
#!wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
#!unzip -q data.zip

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font style="color:blue">Step 2B: Explore the Data [5 Points]</font><a name="step2b"></a>
#
# Here are  some examples:

# %% [markdown]
# ### <font style="color:green">Folder Structure </font>

# %%
# data_path_prefix = "../../../../data/cat_dog_panda_kaggle/" 
data_path_prefix = "./" 
# !tree -d ./cat-dog-panda
# Out:
# /bin/sh: 1: tree: not found

# %% [markdown]
# ### <font style="color:green">Import the Datasets Module</font>
#
# Load the data,  using the datasets module, and . , check out its structure .

# %%
from torchvision import datasets

# %% [markdown]
# ### <font style="color:green">Create a Dataset Object </font>

# %%
train_data = datasets.ImageFolder(data_path_prefix + "./cat-dog-panda/training")
validation_data = datasets.ImageFolder(data_path_prefix + "./cat-dog-panda/validation")

# %% [markdown]
# ### <font style="color:green">List the Classes</font>
#
# It simply prints the sub folders present under the training or validation folder.

# %%
print(train_data.classes)
print(validation_data.classes)
# Out:
# ['cat', 'dog', 'panda']
# ['cat', 'dog', 'panda']

# %% [markdown]
# ### <font style="color:green">Get the Class ID to Name Mapping</font>

# %%
print(train_data.class_to_idx)
print(validation_data.class_to_idx)
# Out:
# {'cat': 0, 'dog': 1, 'panda': 2}
# {'cat': 0, 'dog': 1, 'panda': 2}

# %% [markdown]
# ### <font style="color:red">Find the Number of Samples in Training and Validation Folders [2 Points]</font>

# %%
# Enter Code Here
print(len(train_data))
print(len(validation_data))
# Out:
# 2400
# 600

# %% [markdown]
# ### <font style="color:red">Display Some Samples [3 Points]</font>
# Display one sample from each class. We know that the train dataset contains
#
# - cats from 0 to 799
# - dogs from 800 to 1599
# - pandas from 1600 to 2399
#
# Take one sample from each class and display using matplotlib

# %%
# Enter Code Here
img, target = train_data[5]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (499, 332), target: 0

# %%
# Enter Code Here
img, target = train_data[850]

print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (368, 499), target: 1

# %%
# Enter Code Here
img, target = train_data[1650]
print('image size: {}, target: {}'.format(img.size, target))

plt.imshow(img)
plt.show()
# Out:
# image size: (500, 375), target: 2

# %% [markdown]
# **Note:** The images are all of different size.

# %% [markdown]
# # <font style="color:blue">Step 2C: Create Sample Data</font><a name="step2c"></a>
#
# Take `5%` images from training and validation to create a small sample dataset, which will check our training pipeline.

# %%
import torch
import numpy as np

# %%
subset_size = .05

# %% [markdown]
# ### <font style="color:green">Create a Subset From the Original Data</font>
#
# Instead of copying the original data, use the `Subset` method in `Torch` to create a subset of the data. And use this to train the model.
#
#
# This is new. Let’ss see how it is done.

# %%
train_subset = torch.utils.data.Subset(train_data,np.arange(0,len(train_data),1./subset_size))
validation_subset = torch.utils.data.Subset(validation_data,np.arange(0,len(validation_data),1./subset_size))

# %%
train_subset_loader = torch.utils.data.DataLoader(train_subset,
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)
validation_subset_loader = torch.utils.data.DataLoader(validation_subset, 
                                         batch_size=8,
                                         num_workers=1,
                                         shuffle=False)

# %%
print("Train Subset Size: {}".format(len(train_subset_loader.dataset)))
print("Validation Subset Size: {}".format(len(validation_subset_loader.dataset)))
# Out:
# Train Subset Size: 120
# Validation Subset Size: 30

# %% [markdown]
# You can see that the subset data is only 5% of the original training and validation data.

# %% [markdown]
# We will create a separate function called `subset_data_loader` to create data loaders for subsets.

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation [5 Points]</font>  <a name="step3"></a>
#
# Now that you have seen how the data is organized, configure the train and test loaders to feed  the training pipeline.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ## <font style="color:blue">3.2. Image Transforms</font>
#
# We need to normalize the data. Some of the  standard ways of doing it is to, subtract the mean, make all images equal in size or to rescale the range to \[0,1\] etc. , Use the following functions to do this:

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>
# Normalize for mean and std.
#
# You can add any other transforms here as per your dataset.

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>
# Function for getting mean and variance

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)
    
    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)
    
    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i] 
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]
    
    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)
    
    # var[X] = E[X**2] - E[X]**2
    
    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2
    
    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)
        
    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
#
# Data loader used by the training routine to  generate batches of data:

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ### <font style="color:green">3.3.2. Data Loader for Subset</font>
# Data loader which uses the `subset` to generate batches

# %%
def subset_data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

    loader = torch.utils.data.DataLoader(data_subset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:red">3.4. Prepare Data [5 Points]</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    
    train_data_path = os.path.join(data_root, 'training')
       
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
   
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        # train_transforms = data_augmentation_preprocess(mean, std)
        train_transforms = transforms.Compose([
            transforms.RandomChoice([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
#               transforms.RandomRotation(20, fill=(0,)),
                transforms.RandomRotation(20),
                transforms.RandomCrop(28, padding=4)
            ]),
            common_transforms
   ])
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    
    train_loader = subset_data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    
    test_data_path = os.path.join(data_root, 'validation')
    
    test_loader = subset_data_loader(test_data_path, 
                              train_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    return train_loader, test_loader

# %% [markdown]
# ### <font style="color:red">Question </font>[5 Points]
#
# There are two mistakes in the above code snippet. Spot the errors and correct them all. (Note: The rest of the code will run, even if you fail to find the mistakes.)

# %% [markdown]
# # <font style="color:blue">Step 4: Train a Simple Model</font><a name="step4"></a>
#
# It is time to create the training pipeline and train a simple model on the sample data. We provide most of the code in this section. In the next notebook,  you  are the one who will have to make all the changes.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [ 5 Points]</font>
#
# In this section, define the training  and system configurations. Also, specify the batch size, data path, learning rate etc.
#
#
# ### <font style="color:red">Question </font>[5 Points]:
#
# Set up the training pipeline with a batch size of `4`. Run the experiment then for `100` epochs. Change the configurations as given below:

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 4 
    epochs_count: int = 100  
    init_learning_rate: float = 0.0001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = data_path_prefix + "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You already know the training function. No need to make any changes:

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
):
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
):
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        with torch.no_grad():
            output = model(data)
        
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir=data_path_prefix + 'models', model_file_name='cat_dog_panda_classifier_part1.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir=data_path_prefix + 'models', model_file_name='cat_dog_panda_classifier_part1.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Please note here that before calling the train function, we calculate the validation loss.  It should be close to $log(\text{num_classes})$ and the accuracy should be close to  $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, 
                                                                                   init_val_accuracy*100))
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">4.8. Define Model</font>
#
# In the section,  define the CNN model and train the model.

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=64*52*52, out_features=1024), 
            nn.ReLU(inplace=True),
            
            nn.Linear(in_features=1024, out_features=3)
            
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x

# %% [markdown]
# ## <font style="color:blue">4.9. Training</font>

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=173056, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=True)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2735, 0.2641, 0.2617])
#
# Test set: Average loss: 1.0932, Accuracy: 10/30 (33%)
#
# Initial Test Loss : 1.093247,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 2.632524 Acc: 0.3125
# Elapsed 15.67s, 15.67 s/epoch, 1.96 s/batch, ets 1551.76s
#
# Test set: Average loss: 1.2559, Accuracy: 9/30 (30%)
#
# Model Improved. Saving the Model...
#
# Epoch: 1
# Train Loss: 1.179618 Acc: 0.3594
# Elapsed 40.56s, 20.28 s/epoch, 2.54 s/batch, ets 1987.47s
#
# Test set: Average loss: 1.0444, Accuracy: 9/30 (30%)
#
# Model Improved. Saving the Model...
#
# Epoch: 2
# Train Loss: 0.954982 Acc: 0.5469
# Elapsed 65.17s, 21.72 s/epoch, 2.72 s/batch, ets 2107.19s
#
# Test set: Average loss: 1.0369, Accuracy: 15/30 (50%)
#
# Model Improved. Saving the Model...
#
# Epoch: 3
# Train Loss: 0.942050 Acc: 0.5781
# Elapsed 91.16s, 22.79 s/epoch, 2.85 s/batch, ets 2187.93s
#
# Test set: Average loss: 1.0108, Accuracy: 14/30 (47%)
#
# Model Improved. Saving the Model...
#
# Epoch: 4
# Train Loss: 0.918140 Acc: 0.5703
# Elapsed 116.23s, 23.25 s/epoch, 2.91 s/batch, ets 2208.34s
#
# Test set: Average loss: 0.8153, Accuracy: 18/30 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 5
# Train Loss: 0.991229 Acc: 0.5391
# Elapsed 141.55s, 23.59 s/epoch, 2.95 s/batch, ets 2217.67s
#
# Test set: Average loss: 0.8721, Accuracy: 19/30 (63%)
#
# Epoch: 6
# Train Loss: 0.806961 Acc: 0.6797
# Elapsed 160.88s, 22.98 s/epoch, 2.87 s/batch, ets 2137.44s
#
# Test set: Average loss: 0.8511, Accuracy: 18/30 (60%)
#
# Epoch: 7
# Train Loss: 0.776262 Acc: 0.7109
# Elapsed 179.39s, 22.42 s/epoch, 2.80 s/batch, ets 2063.02s
#
# Test set: Average loss: 0.9163, Accuracy: 13/30 (43%)
#
# Epoch: 8
# Train Loss: 0.702999 Acc: 0.7109
# Elapsed 198.44s, 22.05 s/epoch, 2.76 s/batch, ets 2006.43s
#
# Test set: Average loss: 0.7866, Accuracy: 21/30 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 9
# Train Loss: 0.626760 Acc: 0.7500
# Elapsed 222.78s, 22.28 s/epoch, 2.78 s/batch, ets 2005.03s
#
# Test set: Average loss: 0.8308, Accuracy: 17/30 (57%)
#
# Epoch: 10
# Train Loss: 0.613437 Acc: 0.7578
# Elapsed 241.88s, 21.99 s/epoch, 2.75 s/batch, ets 1957.06s
#
# Test set: Average loss: 0.8816, Accuracy: 18/30 (60%)
#
# Epoch: 11
# Train Loss: 0.554908 Acc: 0.7891
# Elapsed 261.27s, 21.77 s/epoch, 2.72 s/batch, ets 1915.95s
#
# Test set: Average loss: 0.8023, Accuracy: 20/30 (67%)
#
# Epoch: 12
# Train Loss: 0.513321 Acc: 0.8047
# Elapsed 280.03s, 21.54 s/epoch, 2.69 s/batch, ets 1874.08s
#
# Test set: Average loss: 0.9778, Accuracy: 16/30 (53%)
#
# Epoch: 13
# Train Loss: 0.538921 Acc: 0.7578
# Elapsed 298.62s, 21.33 s/epoch, 2.67 s/batch, ets 1834.37s
#
# Test set: Average loss: 0.7185, Accuracy: 18/30 (60%)
#
# Model Improved. Saving the Model...
#
# Epoch: 14
# Train Loss: 0.494841 Acc: 0.8281
# Elapsed 325.73s, 21.72 s/epoch, 2.71 s/batch, ets 1845.79s
#
# Test set: Average loss: 1.0769, Accuracy: 16/30 (53%)
#
# Epoch: 15
# Train Loss: 0.540288 Acc: 0.7891
# Elapsed 345.38s, 21.59 s/epoch, 2.70 s/batch, ets 1813.26s
#
# Test set: Average loss: 0.8246, Accuracy: 18/30 (60%)
#
# Epoch: 16
# Train Loss: 0.446778 Acc: 0.8047
# Elapsed 364.80s, 21.46 s/epoch, 2.68 s/batch, ets 1781.10s
#
# Test set: Average loss: 0.8994, Accuracy: 19/30 (63%)
#
# Epoch: 17
# Train Loss: 0.409115 Acc: 0.8672
# Elapsed 383.87s, 21.33 s/epoch, 2.67 s/batch, ets 1748.74s
#
# Test set: Average loss: 0.8526, Accuracy: 16/30 (53%)
#
# Epoch: 18
# Train Loss: 0.465052 Acc: 0.7969
# Elapsed 403.98s, 21.26 s/epoch, 2.66 s/batch, ets 1722.25s
#
# Test set: Average loss: 0.8123, Accuracy: 19/30 (63%)
#
# Epoch: 19
# Train Loss: 0.447511 Acc: 0.7969
# Elapsed 424.11s, 21.21 s/epoch, 2.65 s/batch, ets 1696.45s
#
# Test set: Average loss: 0.8563, Accuracy: 18/30 (60%)
#
# Epoch: 20
# Train Loss: 0.318470 Acc: 0.8672
# Elapsed 443.88s, 21.14 s/epoch, 2.64 s/batch, ets 1669.82s
#
# Test set: Average loss: 0.8534, Accuracy: 17/30 (57%)
#
# Epoch: 21
# Train Loss: 0.358869 Acc: 0.8516
# Elapsed 462.45s, 21.02 s/epoch, 2.63 s/batch, ets 1639.59s
#
# Test set: Average loss: 0.7761, Accuracy: 22/30 (73%)
#
# Epoch: 22
# Train Loss: 0.397790 Acc: 0.8125
# Elapsed 482.82s, 20.99 s/epoch, 2.62 s/batch, ets 1616.41s
#
# Test set: Average loss: 0.8722, Accuracy: 18/30 (60%)
#
# Epoch: 23
# Train Loss: 0.283123 Acc: 0.9219
# Elapsed 504.14s, 21.01 s/epoch, 2.63 s/batch, ets 1596.44s
#
# Test set: Average loss: 0.9288, Accuracy: 17/30 (57%)
#
# Epoch: 24
# Train Loss: 0.416583 Acc: 0.8750
# Elapsed 523.83s, 20.95 s/epoch, 2.62 s/batch, ets 1571.48s
#
# Test set: Average loss: 0.6862, Accuracy: 23/30 (77%)
#
# Model Improved. Saving the Model...
#
# Epoch: 25
# Train Loss: 0.350822 Acc: 0.8438
# Elapsed 550.56s, 21.18 s/epoch, 2.65 s/batch, ets 1566.99s
#
# Test set: Average loss: 0.9615, Accuracy: 21/30 (70%)
#
# Epoch: 26
# Train Loss: 0.375401 Acc: 0.8594
# Elapsed 569.74s, 21.10 s/epoch, 2.64 s/batch, ets 1540.41s
#
# Test set: Average loss: 0.7922, Accuracy: 18/30 (60%)
#
# Epoch: 27
# Train Loss: 0.386897 Acc: 0.8281
# Elapsed 590.27s, 21.08 s/epoch, 2.64 s/batch, ets 1517.84s
#
# Test set: Average loss: 0.8068, Accuracy: 18/30 (60%)
#
# Epoch: 28
# Train Loss: 0.489016 Acc: 0.7734
# Elapsed 609.00s, 21.00 s/epoch, 2.62 s/batch, ets 1490.99s
#
# Test set: Average loss: 1.0073, Accuracy: 16/30 (53%)
#
# Epoch: 29
# Train Loss: 0.380930 Acc: 0.8125
# Elapsed 627.58s, 20.92 s/epoch, 2.61 s/batch, ets 1464.36s
#
# Test set: Average loss: 0.7440, Accuracy: 21/30 (70%)
#
# Epoch: 30
# Train Loss: 0.395696 Acc: 0.8672
# Elapsed 646.01s, 20.84 s/epoch, 2.60 s/batch, ets 1437.89s
#
# Test set: Average loss: 0.6967, Accuracy: 18/30 (60%)
#
# Epoch: 31
# Train Loss: 0.360040 Acc: 0.8438
# Elapsed 664.50s, 20.77 s/epoch, 2.60 s/batch, ets 1412.06s
#
# Test set: Average loss: 0.9234, Accuracy: 19/30 (63%)
#
# Epoch: 32
# Train Loss: 0.289742 Acc: 0.8906
# Elapsed 683.32s, 20.71 s/epoch, 2.59 s/batch, ets 1387.34s
#
# Test set: Average loss: 1.0252, Accuracy: 18/30 (60%)
#
# Epoch: 33
# Train Loss: 0.372275 Acc: 0.8359
# Elapsed 702.11s, 20.65 s/epoch, 2.58 s/batch, ets 1362.92s
#
# Test set: Average loss: 0.8306, Accuracy: 19/30 (63%)
#
# Epoch: 34
# Train Loss: 0.383981 Acc: 0.7734
# Elapsed 720.87s, 20.60 s/epoch, 2.57 s/batch, ets 1338.75s
#
# Test set: Average loss: 0.8118, Accuracy: 20/30 (67%)
#
# Epoch: 35
# Train Loss: 0.401862 Acc: 0.8281
# Elapsed 740.75s, 20.58 s/epoch, 2.57 s/batch, ets 1316.89s
#
# Test set: Average loss: 1.2667, Accuracy: 15/30 (50%)
#
# Epoch: 36
# Train Loss: 0.329765 Acc: 0.8672
# Elapsed 760.33s, 20.55 s/epoch, 2.57 s/batch, ets 1294.62s
#
# Test set: Average loss: 1.0447, Accuracy: 14/30 (47%)
#
# Epoch: 37
# Train Loss: 0.409854 Acc: 0.8359
# Elapsed 779.83s, 20.52 s/epoch, 2.57 s/batch, ets 1272.36s
#
# Test set: Average loss: 0.8406, Accuracy: 17/30 (57%)
#
# Epoch: 38
# Train Loss: 0.302558 Acc: 0.8672
# Elapsed 806.01s, 20.67 s/epoch, 2.58 s/batch, ets 1260.67s
#
# Test set: Average loss: 0.8785, Accuracy: 21/30 (70%)
#
# Epoch: 39
# Train Loss: 0.283988 Acc: 0.8672
# Elapsed 835.07s, 20.88 s/epoch, 2.61 s/batch, ets 1252.61s
#
# Test set: Average loss: 0.9079, Accuracy: 14/30 (47%)
#
# Epoch: 40
# Train Loss: 0.297098 Acc: 0.8594
# Elapsed 869.61s, 21.21 s/epoch, 2.65 s/batch, ets 1251.39s
#
# Test set: Average loss: 0.6100, Accuracy: 20/30 (67%)
#
# Model Improved. Saving the Model...
#
# Epoch: 41
# Train Loss: 0.361586 Acc: 0.8906
# Elapsed 904.67s, 21.54 s/epoch, 2.69 s/batch, ets 1249.31s
#
# Test set: Average loss: 1.0070, Accuracy: 21/30 (70%)
#
# Epoch: 42
# Train Loss: 0.280958 Acc: 0.8828
# Elapsed 933.96s, 21.72 s/epoch, 2.71 s/batch, ets 1238.04s
#
# Test set: Average loss: 1.1108, Accuracy: 16/30 (53%)
#
# Epoch: 43
# Train Loss: 0.336319 Acc: 0.8281
# Elapsed 963.12s, 21.89 s/epoch, 2.74 s/batch, ets 1225.79s
#
# Test set: Average loss: 0.9690, Accuracy: 17/30 (57%)
#
# Epoch: 44
# Train Loss: 0.306930 Acc: 0.8594
# Elapsed 992.42s, 22.05 s/epoch, 2.76 s/batch, ets 1212.96s
#
# Test set: Average loss: 0.9709, Accuracy: 16/30 (53%)
#
# Epoch: 45
# Train Loss: 0.336412 Acc: 0.9141
# Elapsed 1019.11s, 22.15 s/epoch, 2.77 s/batch, ets 1196.35s
#
# Test set: Average loss: 0.7201, Accuracy: 20/30 (67%)
#
# Epoch: 46
# Train Loss: 0.319910 Acc: 0.8672
# Elapsed 1049.36s, 22.33 s/epoch, 2.79 s/batch, ets 1183.32s
#
# Test set: Average loss: 0.5362, Accuracy: 21/30 (70%)
#
# Model Improved. Saving the Model...
#
# Epoch: 47
# Train Loss: 0.296713 Acc: 0.8281
# Elapsed 1084.44s, 22.59 s/epoch, 2.82 s/batch, ets 1174.81s
#
# Test set: Average loss: 0.9987, Accuracy: 22/30 (73%)
#
# Epoch: 48
# Train Loss: 0.262447 Acc: 0.8984
# Elapsed 1113.10s, 22.72 s/epoch, 2.84 s/batch, ets 1158.53s
# Test set: Average loss: 0.5757, Accuracy: 24/30 (80%)
#
# Epoch: 49
# Train Loss: 0.322381 Acc: 0.8672
# Elapsed 1142.77s, 22.86 s/epoch, 2.86 s/batch, ets 1142.77s
#
# Test set: Average loss: 0.8959, Accuracy: 19/30 (63%)
#
# Epoch: 50
# Train Loss: 0.334893 Acc: 0.8438
# Elapsed 1171.67s, 22.97 s/epoch, 2.87 s/batch, ets 1125.72s
#
# Test set: Average loss: 0.6548, Accuracy: 18/30 (60%)
#
# Epoch: 51
# Train Loss: 0.229292 Acc: 0.8828
# Elapsed 1205.70s, 23.19 s/epoch, 2.90 s/batch, ets 1112.96s
#
# Test set: Average loss: 0.9107, Accuracy: 18/30 (60%)
#
# Epoch: 52
# Train Loss: 0.315815 Acc: 0.8438
# Elapsed 1237.74s, 23.35 s/epoch, 2.92 s/batch, ets 1097.62s
#
# Test set: Average loss: 1.2150, Accuracy: 15/30 (50%)
#
# Epoch: 53
# Train Loss: 0.234109 Acc: 0.8984
# Elapsed 1275.64s, 23.62 s/epoch, 2.95 s/batch, ets 1086.65s
#
# Test set: Average loss: 0.8776, Accuracy: 19/30 (63%)
#
# Epoch: 54
# Train Loss: 0.352603 Acc: 0.8125
# Elapsed 1312.96s, 23.87 s/epoch, 2.98 s/batch, ets 1074.24s
#
# Test set: Average loss: 0.7366, Accuracy: 22/30 (73%)
#
# Epoch: 55
# Train Loss: 0.281033 Acc: 0.8750
# Elapsed 1347.93s, 24.07 s/epoch, 3.01 s/batch, ets 1059.09s
#
# Test set: Average loss: 0.8342, Accuracy: 18/30 (60%)
#
# Epoch: 56
# Train Loss: 0.211783 Acc: 0.9219
# Elapsed 1381.05s, 24.23 s/epoch, 3.03 s/batch, ets 1041.85s
#
# Test set: Average loss: 0.9689, Accuracy: 19/30 (63%)
#
# Epoch: 57
# Train Loss: 0.268056 Acc: 0.8750
# Elapsed 1415.89s, 24.41 s/epoch, 3.05 s/batch, ets 1025.30s
#
# Test set: Average loss: 0.8232, Accuracy: 18/30 (60%)
#
# Epoch: 58
# Train Loss: 0.271044 Acc: 0.9062
# Elapsed 1448.51s, 24.55 s/epoch, 3.07 s/batch, ets 1006.59s
#
# Test set: Average loss: 0.8188, Accuracy: 22/30 (73%)
#
# Epoch: 59
# Train Loss: 0.336687 Acc: 0.8281
# Elapsed 1486.52s, 24.78 s/epoch, 3.10 s/batch, ets 991.02s
#
# Test set: Average loss: 1.0519, Accuracy: 14/30 (47%)
#
# Epoch: 60
# Train Loss: 0.392366 Acc: 0.8359
# Elapsed 1526.75s, 25.03 s/epoch, 3.13 s/batch, ets 976.12s
#
# Test set: Average loss: 0.7867, Accuracy: 22/30 (73%)
#
# Epoch: 61
# Train Loss: 0.317077 Acc: 0.8672
# Elapsed 1601.52s, 25.83 s/epoch, 3.23 s/batch, ets 981.57s
#
# Test set: Average loss: 1.3425, Accuracy: 14/30 (47%)
#
# Epoch: 62
# Train Loss: 0.409412 Acc: 0.8125
# Elapsed 1691.70s, 26.85 s/epoch, 3.36 s/batch, ets 993.54s
#
# Test set: Average loss: 1.5102, Accuracy: 13/30 (43%)
#
# Epoch: 63
# Train Loss: 0.414541 Acc: 0.8125
# Elapsed 1809.48s, 28.27 s/epoch, 3.53 s/batch, ets 1017.83s
#
# Test set: Average loss: 1.2334, Accuracy: 14/30 (47%)
#
# Epoch: 64
# Train Loss: 0.272842 Acc: 0.8750
# Elapsed 1924.96s, 29.61 s/epoch, 3.70 s/batch, ets 1036.52s
#
# Test set: Average loss: 0.6866, Accuracy: 23/30 (77%)
#
# Epoch: 65
# Train Loss: 0.314117 Acc: 0.8359
# Elapsed 2036.84s, 30.86 s/epoch, 3.86 s/batch, ets 1049.28s
#
# Test set: Average loss: 0.8509, Accuracy: 19/30 (63%)
#
# Epoch: 66
# Train Loss: 0.339915 Acc: 0.8438
# Elapsed 2154.67s, 32.16 s/epoch, 4.02 s/batch, ets 1061.25s
#
# Test set: Average loss: 0.9993, Accuracy: 18/30 (60%)
#
# Epoch: 67
# Train Loss: 0.330848 Acc: 0.8359
# Elapsed 2269.44s, 33.37 s/epoch, 4.17 s/batch, ets 1067.97s
#
# Test set: Average loss: 0.8922, Accuracy: 18/30 (60%)
#
# Epoch: 68
# Train Loss: 0.273838 Acc: 0.8828
# Elapsed 2374.43s, 34.41 s/epoch, 4.30 s/batch, ets 1066.77s
#
# Test set: Average loss: 1.0155, Accuracy: 19/30 (63%)
#
# Epoch: 69
# Train Loss: 0.302351 Acc: 0.8516
# Elapsed 2461.96s, 35.17 s/epoch, 4.40 s/batch, ets 1055.13s
#
# Test set: Average loss: 0.8748, Accuracy: 17/30 (57%)
#
# Epoch: 70
# Train Loss: 0.280076 Acc: 0.8516
# Elapsed 2554.10s, 35.97 s/epoch, 4.50 s/batch, ets 1043.22s
#
# Test set: Average loss: 1.0111, Accuracy: 15/30 (50%)
#
# Epoch: 71
# Train Loss: 0.442215 Acc: 0.7578
# Elapsed 2647.31s, 36.77 s/epoch, 4.60 s/batch, ets 1029.51s
#
# Test set: Average loss: 0.9810, Accuracy: 18/30 (60%)
#
# Epoch: 72
# Train Loss: 0.281711 Acc: 0.8281
# Elapsed 2738.01s, 37.51 s/epoch, 4.69 s/batch, ets 1012.69s
#
# Test set: Average loss: 0.6943, Accuracy: 18/30 (60%)
#
# Epoch: 73
# Train Loss: 0.279518 Acc: 0.8594
# Elapsed 2825.05s, 38.18 s/epoch, 4.77 s/batch, ets 992.58s
#
# Test set: Average loss: 1.0036, Accuracy: 15/30 (50%)
#
# Epoch: 74
# Train Loss: 0.266414 Acc: 0.8750
# Elapsed 2888.27s, 38.51 s/epoch, 4.81 s/batch, ets 962.76s
#
# Test set: Average loss: 1.0312, Accuracy: 18/30 (60%)
#
# Epoch: 75
# Train Loss: 0.300290 Acc: 0.8516
# Elapsed 2944.03s, 38.74 s/epoch, 4.84 s/batch, ets 929.69s
#
# Test set: Average loss: 0.9524, Accuracy: 18/30 (60%)
#
# Epoch: 76
# Train Loss: 0.258734 Acc: 0.8906
# Elapsed 2999.60s, 38.96 s/epoch, 4.87 s/batch, ets 895.98s
#
# Test set: Average loss: 1.2126, Accuracy: 14/30 (47%)
#
# Epoch: 77
# Train Loss: 0.228131 Acc: 0.9062
# Elapsed 3056.98s, 39.19 s/epoch, 4.90 s/batch, ets 862.23s
#
# Test set: Average loss: 1.3107, Accuracy: 18/30 (60%)
#
# Epoch: 78
# Train Loss: 0.226141 Acc: 0.9062
# Elapsed 3117.22s, 39.46 s/epoch, 4.93 s/batch, ets 828.63s
#
# Test set: Average loss: 1.3129, Accuracy: 13/30 (43%)
#
# Epoch: 79
# Train Loss: 0.360598 Acc: 0.8438
# Elapsed 3176.53s, 39.71 s/epoch, 4.96 s/batch, ets 794.13s
#
# Test set: Average loss: 1.0890, Accuracy: 18/30 (60%)
#
# Epoch: 80
# Train Loss: 0.310281 Acc: 0.8359
# Elapsed 3238.18s, 39.98 s/epoch, 5.00 s/batch, ets 759.57s
#
# Test set: Average loss: 0.8300, Accuracy: 20/30 (67%)
#
# Epoch: 81
# Train Loss: 0.378421 Acc: 0.8047
# Elapsed 3291.24s, 40.14 s/epoch, 5.02 s/batch, ets 722.47s
#
# Test set: Average loss: 0.9160, Accuracy: 21/30 (70%)
#
# Epoch: 82
# Train Loss: 0.301381 Acc: 0.8359
# Elapsed 3322.40s, 40.03 s/epoch, 5.00 s/batch, ets 680.49s
#
# Test set: Average loss: 0.7115, Accuracy: 19/30 (63%)
#
# Epoch: 83
# Train Loss: 0.331079 Acc: 0.8359
# Elapsed 3348.35s, 39.86 s/epoch, 4.98 s/batch, ets 637.78s
#
# Test set: Average loss: 0.9190, Accuracy: 18/30 (60%)
#
# Epoch: 84
# Train Loss: 0.247693 Acc: 0.8828
# Elapsed 3374.44s, 39.70 s/epoch, 4.96 s/batch, ets 595.49s
#
# Test set: Average loss: 0.8223, Accuracy: 20/30 (67%)
#
# Epoch: 85
# Train Loss: 0.212249 Acc: 0.9062
# Elapsed 3398.38s, 39.52 s/epoch, 4.94 s/batch, ets 553.22s
#
# Test set: Average loss: 0.9845, Accuracy: 15/30 (50%)
#
# Epoch: 86
# Train Loss: 0.263855 Acc: 0.8672
# Elapsed 3419.72s, 39.31 s/epoch, 4.91 s/batch, ets 510.99s
#
# Test set: Average loss: 0.8926, Accuracy: 18/30 (60%)
#
# Epoch: 87
# Train Loss: 0.240510 Acc: 0.8750
# Elapsed 3441.51s, 39.11 s/epoch, 4.89 s/batch, ets 469.30s
#
# Test set: Average loss: 1.3226, Accuracy: 18/30 (60%)
#
# Epoch: 88
# Train Loss: 0.299710 Acc: 0.9141
# Elapsed 3463.37s, 38.91 s/epoch, 4.86 s/batch, ets 428.06s
#
# Test set: Average loss: 1.1501, Accuracy: 18/30 (60%)
#
# Epoch: 89
# Train Loss: 0.223223 Acc: 0.9062
# Elapsed 3485.21s, 38.72 s/epoch, 4.84 s/batch, ets 387.25s
#
# Test set: Average loss: 0.8393, Accuracy: 21/30 (70%)
#
# Epoch: 90
# Train Loss: 0.309001 Acc: 0.8438
# Elapsed 3507.40s, 38.54 s/epoch, 4.82 s/batch, ets 346.89s
#
# Test set: Average loss: 0.7054, Accuracy: 21/30 (70%)
#
# Epoch: 91
# Train Loss: 0.263687 Acc: 0.8516
# Elapsed 3529.86s, 38.37 s/epoch, 4.80 s/batch, ets 306.94s
#
# Test set: Average loss: 1.2017, Accuracy: 16/30 (53%)
#
# Epoch: 92
# Train Loss: 0.314027 Acc: 0.8672
# Elapsed 3552.50s, 38.20 s/epoch, 4.77 s/batch, ets 267.39s
#
# Test set: Average loss: 0.7202, Accuracy: 22/30 (73%)
#
# Epoch: 93
# Train Loss: 0.270347 Acc: 0.8828
# Elapsed 3575.52s, 38.04 s/epoch, 4.75 s/batch, ets 228.22s
#
# Test set: Average loss: 1.0194, Accuracy: 20/30 (67%)
#
# Epoch: 94
# Train Loss: 0.280475 Acc: 0.8438
# Elapsed 3598.52s, 37.88 s/epoch, 4.73 s/batch, ets 189.40s
#
# Test set: Average loss: 1.2199, Accuracy: 15/30 (50%)
#
# Epoch: 95
# Train Loss: 0.203885 Acc: 0.9375
# Elapsed 3621.22s, 37.72 s/epoch, 4.72 s/batch, ets 150.88s
#
# Test set: Average loss: 0.7032, Accuracy: 21/30 (70%)
#
# Epoch: 96
# Train Loss: 0.365893 Acc: 0.8516
# Elapsed 3644.29s, 37.57 s/epoch, 4.70 s/batch, ets 112.71s
#
# Test set: Average loss: 0.9469, Accuracy: 18/30 (60%)
#
# Epoch: 97
# Train Loss: 0.171003 Acc: 0.9297
# Elapsed 3667.84s, 37.43 s/epoch, 4.68 s/batch, ets 74.85s
#
# Test set: Average loss: 1.1505, Accuracy: 20/30 (67%)
#
# Epoch: 98
# Train Loss: 0.331868 Acc: 0.8125
# Elapsed 3690.82s, 37.28 s/epoch, 4.66 s/batch, ets 37.28s
#
# Test set: Average loss: 0.9524, Accuracy: 18/30 (60%)
#
# Epoch: 99
# Train Loss: 0.186470 Acc: 0.9141
# Elapsed 3713.62s, 37.14 s/epoch, 4.64 s/batch, ets 0.00s
#
# Test set: Average loss: 0.8054, Accuracy: 18/30 (60%)
#
# Total time: 3714.99, Best Loss: 0.536

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5: Sample Prediction</font><a name="predictions"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    data = batch_input.to(device)
    
    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 4

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2735, 0.2641, 0.2617])

# %% [markdown]
# Ddespite training the network on a very small subset of data, you can see that the predictions are not that bad. This means that our model is ready for training.

# %% [markdown]
# # <font style="color:red">Step 6. Display Mistakes [15 points] </font><a name="display"></a>
#
# The above code displayed sample predictions. But correct predictions are of no use. So, write a similar function that will  display only the mistakes made by the network.
#
#
# **You have to display only 15 images.**

# %%
def get_sample_prediction_miss_classified(model, data_root, mean, std):
    batch_size = 4

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
    
    # It is important to do model.eval() before prediction
    model.eval()
    
    # Send model to cpu/cuda according to your system configuration
    model.to(device)

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = 1 #int(data_len/batch_size)
#     print("interval: ", interval)
    imgs = []
    inputs = []
    targets = []
#     for i in range(batch_size):
    for i in range(50):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    miss_classified_count = 0
    print("targets: ", len(targets))
    for i, target in enumerate(targets):
        if cls[i] != targets[i]:
            plt.subplot(3, 5, miss_classified_count+1)
            img = transforms.functional.to_pil_image(imgs[i])
            plt.imshow(img)
            plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                         prob[i], 
                                                         test_dataset.classes[targets[i]]))
            miss_classified_count += 1
        if miss_classified_count >= 15:
            break
            
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %%
m = MyModel()
m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction_miss_classified(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2735, 0.2641, 0.2617])
# targets:  50

# %% [markdown]
# After completing the assignment, <font style="color:red">upload and submit the notebook on the portal</font> for checking and feedback.
