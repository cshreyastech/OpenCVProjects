# %% [markdown]
# # <font style="color:blue">Table of Content</font>
#
# - [Step 1: Understand Your Problem](#step1)
# - [Step 2: Get the Data](#step2)
# - [Step 3. Data Preparation](#step3)
# - [Step 4: Train a Simple Model](#step4)
# - [Step 5: Sample Prediction](#step5)
# - [Step 6. Display Mistakes](#step6)

# %% [markdown]
# # <font style="color:blue">Project 1 - Part 2: Train an Image Classifier From Scratch</font>
# As discussed in the previous notebook, the steps for training Neural Networks are:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore and understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on full data
# - Step 6 - Improve your model
#
# You have already been through Steps `1-4` in the previous notebook. Use them here as well.
#
# Here, you will implement Steps `5` & `6` from scratch. Design a model that achieves `>=85%` validation accuracy on the given dataset.
#
# There are 70 points for this notebook. The sections which carry marks are in Red.
#
# There are **70 points** for this notebook. <font style="color:red">The sections which carry marks are in Red.</font>

# %% [markdown]
# For GPU compute you can use Kaggle Kernels, Google Colab or any other service of your choice.
#
# After completing the assignment, upload and submit it on the portal for feedback.

# %% [markdown]
# <font style="color:red">Use the full data to train the network. You need to achieve 85% accuracy for validation data to successfully complete this assignment.</font>
#
#
# <font style="color:red">Just remember to build your own model, not use any pre-trained models/weights.</font>
#
#
# Upon completing the assignment, <font style="color:red">upload the notebook and the models folder on the portal for  feedback.</font>

# %% [markdown]
# # <font style="color:blue">Step 1: Understand Your problem </font><a name="step1"></a>
# Already covered in the previous notebook.

# %% [markdown]
# # <font style="color:blue">Step 2: Get the Data </font><a name="step2"></a>
#
# Already covered in the previous notebook.

# %%
#!wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip
# Out:
# --2025-03-26 11:33:48--  https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fo/t88xubtku433w1t10t7he/AEmJ4AwgZ3Svjp29IdawVbE?rlkey=9vuxo0sqr57tsoqn8wgk9pjzc&dl=1 [following]
# --2025-03-26 11:33:48--  https://www.dropbox.com/scl/fo/t88xubtku433w1t10t7he/AEmJ4AwgZ3Svjp29IdawVbE?rlkey=9vuxo0sqr57tsoqn8wgk9pjzc&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com/zip_download_get/CJ-m0jnU7IC5GN_hbKmDl8h7eNLQD2THUtUveUhSNeJXBmZ2PoGFKV_-cdg78C-nxKRgMrGVQEDRAvg2cxN47blL2pvzzusNjSGwR75DNC1FyQ# [following]
# --2025-03-26 11:33:51--  https://uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com/zip_download_get/CJ-m0jnU7IC5GN_hbKmDl8h7eNLQD2THUtUveUhSNeJXBmZ2PoGFKV_-cdg78C-nxKRgMrGVQEDRAvg2cxN47blL2pvzzusNjSGwR75DNC1FyQ
# Resolving uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com (uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com)... 162.125.85.15, 2620:100:6035:15::a27d:550f
# Connecting to uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com (uc4ca29530b6d822f19d2653d542.dl.dropboxusercontent.com)|162.125.85.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 197683526 (189M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 188.53M  10.9MB/s    in 39s
#
# 2025-03-26 11:34:31 (4.83 MB/s) - ‘data.zip’ saved [197683526/197683526]

# %% [markdown]
# ### <font style="color:green">Extract the Data</font>

# %%
#!unzip -q data.zip
# !mkdir models
# !ls
# !pwd
# Out:
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
# cat-dog-panda  data.zip
# /kaggle/working

# %%
# data_path_prefix = "../../../../data/"
data_path_prefix = "./"
# !tree -d ./cat-dog-panda

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font><a name="step3"></a>
# Already covered in the previous notebook.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary Preprocessing Transforms</font>

# %%
def image_preprocess_transforms():

    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])

    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()

    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])

    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>

# %%
def get_mean_std(data_root, num_workers=4):

    transform = image_preprocess_transforms()

    loader = data_loader(data_root, transform)

    batch_mean = torch.zeros(3)
    batch_mean_sqrd = torch.zeros(3)

    for batch_data, _ in loader:
        batch_mean += batch_data.mean(dim=(0, 2, 3)) # E[batch_i]
        batch_mean_sqrd += (batch_data ** 2).mean(dim=(0, 2, 3)) #  E[batch_i**2]

    # E[dataset] = E[E[batch_1], E[batch_2], ...]
    mean = batch_mean / len(loader)

    # var[X] = E[X**2] - E[X]**2

    # E[X**2] = E[E[batch_1**2], E[batch_2**2], ...]
    # E[X]**2 = E[E[batch_1], E[batch_2], ...] ** 2

    var = (batch_mean_sqrd / len(loader)) - (mean ** 2)

    std = var ** 0.5
    print('mean: {}, std: {}'.format(mean, std))

    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)

    loader = torch.utils.data.DataLoader(dataset,
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)

    return loader

# %%
# def data_loader(data_root, transform, batch_size=8, shuffle=False, num_workers=2, subset_size=0.05):
#     dataset = datasets.ImageFolder(root=data_root, transform=transform)

#     data_subset = torch.utils.data.Subset(dataset,np.arange(0,len(dataset),1./subset_size).astype(int))

#     loader = torch.utils.data.DataLoader(data_subset,
#                                          batch_size=batch_size,
#                                          num_workers=num_workers,
#                                          shuffle=shuffle)

#     return loader

# %% [markdown]
# ## <font style="color:green">3.4. Prepare Data</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
    # YOUR CODE HERE
    # common transforms
    train_data_path = os.path.join(data_root, 'training')
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    common_transforms = image_common_transforms(mean, std)

    # if data_augmentation is true
    # data augmentation implementation
    if data_augmentation:
        train_transforms = transforms.Compose([
            transforms.RandomChoice([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
#                 transforms.RandomRotation(20),
#                 transforms.RandomCrop(28, padding=4),
                # transforms.PILToTensor(),
                # transforms.ConvertImageDtype(torch.float),
                transforms.RandomPerspective(distortion_scale=0.6, p=1),
                transforms.ColorJitter(brightness=.5, hue=.3)
            ]),
            common_transforms
        ])
    # else do common transforms
    else:
        train_transforms = common_transforms



    # train dataloader
    train_loader = data_loader(train_data_path,
                               train_transforms,
                               batch_size=batch_size,
                               shuffle=True,
                               num_workers=num_workers)

    # test dataloader

    test_data_path = os.path.join(data_root, 'validation')

    test_loader = data_loader(test_data_path,
                              train_transforms,
                              batch_size=batch_size,
                              shuffle=False,
                              num_workers=num_workers)

    return train_loader, test_loader

# %% [markdown]
# # <font style="color:blue">Step 4: Train Your Model</font><a name="step4"></a>
#
# Now, create the training pipeline, and train your model on the full data.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [20 Points]</font>
#
# To achieve good results, change the parameters given in these configurations. Score 20 points for all right choices.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>
#
# Fix the seed (e.g., `21`) to get a reproducible result.

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 64
    epochs_count: int = 251
    init_learning_rate: float = 0.001  # initial learning rate for lr scheduler
    log_interval: int = 5000
    test_interval: int = 10
    # data_root: str = data_path_prefix + "./cat-dog-panda"
    # model_dir: str = data_path_prefix + "models"
    data_root: str = os.path.join(data_path_prefix, "cat-dog-panda")
    model_dir: str = os.path.join(data_path_prefix, "models")

    model_file_name: str = 'cat_dog_panda_classifier_part2.pt'
    num_workers: int = 2
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
#
# You are already familiar with the training function. No changes needed here.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:

    # change model in training mood
    model.train()

    # to get batch loss
    batch_loss = np.array([])

    # to get batch accuracy
    batch_acc = np.array([])

    for batch_idx, (data, target) in enumerate(train_loader):

        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()

        # forward pass to the model
        output = model(data)

        # cross entropy loss
        loss = F.cross_entropy(output, target)

        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()

        batch_loss = np.append(batch_loss, [loss.item()])

        # Score to probability using softmax
        prob = F.softmax(output, dim=1)

        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]

        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()

        # accuracy
        acc = float(correct) / float(len(data))

        batch_acc = np.append(batch_acc, [acc])

    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    #
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)

        target = target.to(train_config.device)

        with torch.no_grad():
            output = model(data)

        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()

        # Score to probability using softmax
        prob = F.softmax(output, dim=1)

        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]

        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)

    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)

    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )

    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, epoch, loss, device, model_dir, model_file_name):

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'epoch': epoch
    }

    torch.save(checkpoint, model_path)

    if device == 'cuda':
        model.to('cuda')

    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir, model_file_name):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    checkpoint = torch.load(model_path)

    model.load_state_dict(checkpoint['model_state_dict'])
    epoch = checkpoint['epoch']

    return model, epoch

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# Note: Before calling the train function, we calculate the validation loss, which we know should be close to $\log(\text{num_classes})$. Also, the accuracy should be close to $\frac{1}{\text{num_classes}}$.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(),
         training_configuration=TrainingConfiguration(), data_augmentation=True):

    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count
    model_dir = train_config.model_dir
    model_file_name = train_config.model_file_name
    device = training_configuration.device
    epoch_completed = 0

    model_path = os.path.join(model_dir, model_file_name)
    if os.path.exists(model_path):
        print("main() checkpoint exist- model_file_name", model_file_name)
        model, epoch_completed = load_model(model, model_dir, model_file_name)
    else:
        print("main() checkpoint does not exist- model_file_name", model_file_name)

    # if GPU is available use training config,
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )

    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )

    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)

    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])

    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])

    # Calculate Initial Test Loss
    init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
    print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss,
                                                                                   init_val_accuracy*100))

    # trainig time measurement
    t_begin = time.time()
    for epoch in range(epoch_completed + 1, training_configuration.epochs_count):
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)

        epoch_train_loss = np.append(epoch_train_loss, [train_loss])

        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time

        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)

            epoch_test_loss = np.append(epoch_test_loss, [current_loss])

            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])

            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                # save_model(model, epoch, current_loss, device=training_configuration.device)
                save_model(model, epoch, current_loss, device, model_dir, model_file_name)

    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))

    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors,
                       loss_legend_loc='upper center', acc_legend_loc='upper left',
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):

    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()

    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])

    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))

        min_train_loss = train_loss[i].min()

        min_val_loss = val_loss[i].min()

        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]),
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]),
                 label="VALID LOSS ({0:.4})".format(min_val_loss))

    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')

    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])

    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))

        max_train_acc = train_acc[i].max()

        max_val_acc = val_acc[i].max()

        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]),
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]),
                 label="VALID ACC ({0:.4})".format(max_val_acc))

    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')

    fig.savefig('sample_loss_acc_plot.png')
    plt.show()

    return

# %% [markdown]
# ## <font style="color:red">4.8. Define Model [20 Points]</font>
#
# Next, define the CNN model. Keep iterating. Do this by training various models. Just ,change the :
#
# - number of layers
# - parameters inside the layers
# - different types of layers

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(3, 32, kernel_size=5, padding=1)
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(128)

        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(256)

        self.conv5 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(512)


        # Fully connected layers
        self.fc1 = nn.Linear(512 * 6 * 6, 1024)
    
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, 128)
        self.fc5 = nn.Linear(128, 64)
        self.fc6 = nn.Linear(64, 3)

    def forward(self, x):
        # Convolutional feature extraction
        # n_out = floor((n_in + 2p - k) / s) + 1

        x = F.relu(self.bn1(self.conv1(x)))
        # n_out = floor((224 + 2 x 1 - 5) / 1) + 1 = 222
        # [16, 32, 222, 222]
#         print("self.bn1---------------: ", x.shape)

        x = F.max_pool2d(x, kernel_size=2)
        # n_out = floor((222 + 2 x 0 - 2) / 2) + 1 = 111
        # [16, 32, 111, 111]
#         print("max_pool2d---------------: ", x.shape)


        x = F.relu(self.bn2(self.conv2(x)))
        # [16, 64, 111, 111]
#         print("self.bn2---------------: ", x.shape)

        x = F.max_pool2d(x, kernel_size=2)
        # n_out = floor((55 + 2 x 0 - 2) / 2) + 1 = 55
        # [16, 64, 55, 55]
#         print("max_pool2d---------------: ", x.shape)

        x = F.relu(self.bn3(self.conv3(x)))
        # [16, 128, 55, 55]
#         print("self.bn3---------------: ", x.shape)

        x = F.max_pool2d(x, kernel_size=2)
        # n_out = floor((55 + 2 x 0 - 2) / 2) + 1 = 27
        # [16, 128, 27, 27]
        # print("max_pool2d---------------: ", x.shape)

        x = F.relu(self.bn4(self.conv4(x)))
        # [16, 256, 27, 27]
#         print("self.bn4---------------: ", x.shape)

        x = F.max_pool2d(x, kernel_size=2)
        # n_out = floor((27 + 2 x 0 - 2) / 2) + 1 = 13
        # [16, 256, 13, 13]
#         print("max_pool2d---------------: ", x.shape)

        # -----------------------------------
        x = F.relu(self.bn5(self.conv5(x)))
        # [16, 512, 13, 13]
#         print("self.bn5---------------: ", x.shape)

        x = F.max_pool2d(x, kernel_size=2)
        # n_out = floor((13 + 2 x 0 - 2) / 2) + 1 = 6
        # [16, 512, 6, 6]
#         print("max_pool2d---------------: ", x.shape)


        # Flatten before feeding to fully connected layers
        x = x.view(x.size(0), -1)

        # Fully connected classification head
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.fc2(x))
#         x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.fc3(x))
        x = F.dropout(x, p=0.5, training=self.training)

        x = F.relu(self.fc4(x))
#         x = F.dropout(x, p=0.5, training=self.training)

        x = F.relu(self.fc5(x))
        x = F.dropout(x, p=0.5, training=self.training)

        x = self.fc6(x)  # No activation here as it's likely for classification

        return x

# %%
# class MyModel(nn.Module):
#     def __init__(self):
#         super().__init__()

#         # convolution layers
#         self._body = nn.Sequential(
#             nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2),

#             nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2),
#         )


#         # Fully connected layers
#         self._head = nn.Sequential(
#             nn.Linear(in_features=64*52*52, out_features=1024),
#             nn.ReLU(inplace=True),

#             nn.Linear(in_features=1024, out_features=3)

#         )

#     def forward(self, x):

#         # apply feature extractor
#         x = self._body(x)
#         # flatten the output of conv layers
#         # dimension should be batch_size * number_of weight_in_last conv_layer
#         x = x.view(x.size()[0], -1)
#         # apply classification head
#         x = self._head(x)


#         return x

# %% [markdown]
# ## <font style="color:red">4.9. Training [20 Points]</font>
#
# Experiment with:
#
# - Optimizers and learning rate schedulers \[You can  get good results even without a learning rate scheduler\]
#
# - Regularization techniques like Data Augmentation, Dropout, BatchNorm

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

factor = 0.1  # reduce by factor 0.5
patience = 10  # epochs
threshold = 0.0001
mode = 'min'
### CHANGE HERE ###

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate,
#     betas=(0.9, 0.999),
#     eps=1e-08,
#     weight_decay=0, #turn
#     amsgrad=False
)

# decay_rate = 0.9
# scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=decay_rate)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode=mode, factor=factor, patience=patience, threshold=threshold)
# Out:
# MyModel(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=18432, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=128, bias=True)
#   (fc5): Linear(in_features=128, out_features=64, bias=True)
#   (fc6): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=scheduler, data_augmentation=True)
# Out:
# main() checkpoint does not exist- model_file_name cat_dog_panda_classifier_part2.pt
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])
#
# Test set: Average loss: 1.1016, Accuracy: 200/600 (33%)
#
# Initial Test Loss : 1.101558,
# Initial Test Accuracy : 33.333%
#
# Epoch: 1
# Train Loss: 0.975604 Acc: 0.5053
# Elapsed 12.46s, 6.23 s/epoch, 0.16 s/batch, ets 1551.65s
# Epoch: 2
# Train Loss: 0.835019 Acc: 0.5617
# Elapsed 25.06s, 8.35 s/epoch, 0.22 s/batch, ets 2071.65s
# Epoch: 3
# Train Loss: 0.779703 Acc: 0.5732
# Elapsed 37.17s, 9.29 s/epoch, 0.24 s/batch, ets 2294.95s
# Epoch: 4
# Train Loss: 0.764234 Acc: 0.5859
# Elapsed 49.82s, 9.96 s/epoch, 0.26 s/batch, ets 2451.16s
# Epoch: 5
# Train Loss: 0.755428 Acc: 0.5769
# Elapsed 61.78s, 10.30 s/epoch, 0.27 s/batch, ets 2522.53s
# Epoch: 6
# Train Loss: 0.735984 Acc: 0.6024
# Elapsed 74.34s, 10.62 s/epoch, 0.28 s/batch, ets 2591.13s
# Epoch: 7
# Train Loss: 0.701875 Acc: 0.6065
# Elapsed 86.09s, 10.76 s/epoch, 0.28 s/batch, ets 2615.13s
# Epoch: 8
# Train Loss: 0.731441 Acc: 0.5913
# Elapsed 98.01s, 10.89 s/epoch, 0.29 s/batch, ets 2635.42s
# Epoch: 9
# Train Loss: 0.723709 Acc: 0.6020
# Elapsed 110.81s, 11.08 s/epoch, 0.29 s/batch, ets 2670.40s
# Epoch: 10
# Train Loss: 0.686150 Acc: 0.6250
# Elapsed 122.89s, 11.17 s/epoch, 0.29 s/batch, ets 2681.29s
#
# Test set: Average loss: 2.1104, Accuracy: 218/600 (36%)
#
# Model Improved. Saving the Model...
#
# Epoch: 11
# Train Loss: 0.713252 Acc: 0.6283
# Elapsed 138.41s, 11.53 s/epoch, 0.30 s/batch, ets 2756.68s
# Epoch: 12
# Train Loss: 0.670462 Acc: 0.6205
# Elapsed 150.53s, 11.58 s/epoch, 0.30 s/batch, ets 2755.88s
# Epoch: 13
# Train Loss: 0.685711 Acc: 0.6262
# Elapsed 162.51s, 11.61 s/epoch, 0.31 s/batch, ets 2751.11s
# Epoch: 14
# Train Loss: 0.649481 Acc: 0.6468
# Elapsed 174.94s, 11.66 s/epoch, 0.31 s/batch, ets 2752.42s
# Epoch: 15
# Train Loss: 0.666376 Acc: 0.6291
# Elapsed 186.91s, 11.68 s/epoch, 0.31 s/batch, ets 2745.21s
# Epoch: 16
# Train Loss: 0.643487 Acc: 0.6377
# Elapsed 198.87s, 11.70 s/epoch, 0.31 s/batch, ets 2737.43s
# Epoch: 17
# Train Loss: 0.681411 Acc: 0.6250
# Elapsed 211.27s, 11.74 s/epoch, 0.31 s/batch, ets 2734.75s
# Epoch: 18
# Train Loss: 0.633830 Acc: 0.6447
# Elapsed 223.04s, 11.74 s/epoch, 0.31 s/batch, ets 2723.42s
# Epoch: 19
# Train Loss: 0.667717 Acc: 0.6419
# Elapsed 235.45s, 11.77 s/epoch, 0.31 s/batch, ets 2719.41s
# Epoch: 20
# Train Loss: 0.630453 Acc: 0.6460
# Elapsed 247.46s, 11.78 s/epoch, 0.31 s/batch, ets 2710.33s
#
# Test set: Average loss: 0.6634, Accuracy: 379/600 (63%)
#
# Model Improved. Saving the Model...
#
# Epoch: 21
# Train Loss: 0.624949 Acc: 0.6303
# Elapsed 262.74s, 11.94 s/epoch, 0.31 s/batch, ets 2734.84s
# Epoch: 22
# Train Loss: 0.616935 Acc: 0.6505
# Elapsed 275.24s, 11.97 s/epoch, 0.31 s/batch, ets 2728.45s
# Epoch: 23
# Train Loss: 0.609751 Acc: 0.6620
# Elapsed 287.90s, 12.00 s/epoch, 0.32 s/batch, ets 2723.05s
# Epoch: 24
# Train Loss: 0.612449 Acc: 0.6669
# Elapsed 300.75s, 12.03 s/epoch, 0.32 s/batch, ets 2718.81s
# Epoch: 25
# Train Loss: 0.618254 Acc: 0.6805
# Elapsed 312.77s, 12.03 s/epoch, 0.32 s/batch, ets 2706.63s
# Epoch: 26
# Train Loss: 0.595162 Acc: 0.6632
# Elapsed 324.79s, 12.03 s/epoch, 0.32 s/batch, ets 2694.56s
# Epoch: 27
# Train Loss: 0.579189 Acc: 0.6793
# Elapsed 337.33s, 12.05 s/epoch, 0.32 s/batch, ets 2686.61s
# Epoch: 28
# Train Loss: 0.574654 Acc: 0.6846
# Elapsed 349.68s, 12.06 s/epoch, 0.32 s/batch, ets 2676.87s
# Epoch: 29
# Train Loss: 0.588902 Acc: 0.6805
# Elapsed 361.85s, 12.06 s/epoch, 0.32 s/batch, ets 2665.65s
# Epoch: 30
# Train Loss: 0.565539 Acc: 0.6854
# Elapsed 374.23s, 12.07 s/epoch, 0.32 s/batch, ets 2655.85s
#
# Test set: Average loss: 1.0334, Accuracy: 365/600 (61%)
#
# Epoch: 31
# Train Loss: 0.583658 Acc: 0.6933
# Elapsed 389.00s, 12.16 s/epoch, 0.32 s/batch, ets 2662.22s
# Epoch: 32
# Train Loss: 0.576356 Acc: 0.7002
# Elapsed 401.69s, 12.17 s/epoch, 0.32 s/batch, ets 2653.61s
# Epoch: 33
# Train Loss: 0.574118 Acc: 0.6785
# Elapsed 413.81s, 12.17 s/epoch, 0.32 s/batch, ets 2641.09s
# Epoch: 34
# Train Loss: 0.613588 Acc: 0.6711
# Elapsed 426.16s, 12.18 s/epoch, 0.32 s/batch, ets 2630.03s
# Epoch: 35
# Train Loss: 0.611382 Acc: 0.6776
# Elapsed 439.03s, 12.20 s/epoch, 0.32 s/batch, ets 2622.01s
# Epoch: 36
# Train Loss: 0.574518 Acc: 0.6924
# Elapsed 451.08s, 12.19 s/epoch, 0.32 s/batch, ets 2608.93s
# Epoch: 37
# Train Loss: 0.553487 Acc: 0.6974
# Elapsed 463.61s, 12.20 s/epoch, 0.32 s/batch, ets 2598.67s
# Epoch: 38
# Train Loss: 0.572316 Acc: 0.6834
# Elapsed 475.71s, 12.20 s/epoch, 0.32 s/batch, ets 2585.92s
# Epoch: 39
# Train Loss: 0.566914 Acc: 0.6920
# Elapsed 488.03s, 12.20 s/epoch, 0.32 s/batch, ets 2574.34s
# Epoch: 40
# Train Loss: 0.540081 Acc: 0.7002
# Elapsed 500.46s, 12.21 s/epoch, 0.32 s/batch, ets 2563.33s
#
# Test set: Average loss: 0.6166, Accuracy: 415/600 (69%)
#
# Model Improved. Saving the Model...
#
# Epoch: 41
# Train Loss: 0.546953 Acc: 0.7159
# Elapsed 516.05s, 12.29 s/epoch, 0.32 s/batch, ets 2567.97s
# Epoch: 42
# Train Loss: 0.544211 Acc: 0.7134
# Elapsed 528.67s, 12.29 s/epoch, 0.32 s/batch, ets 2557.30s
# Epoch: 43
# Train Loss: 0.552235 Acc: 0.7023
# Elapsed 540.69s, 12.29 s/epoch, 0.32 s/batch, ets 2543.72s
# Epoch: 44
# Train Loss: 0.547258 Acc: 0.7060
# Elapsed 552.60s, 12.28 s/epoch, 0.32 s/batch, ets 2529.69s
# Epoch: 45
# Train Loss: 0.556135 Acc: 0.7134
# Elapsed 565.27s, 12.29 s/epoch, 0.32 s/batch, ets 2519.14s
# Epoch: 46
# Train Loss: 0.543958 Acc: 0.7159
# Elapsed 577.16s, 12.28 s/epoch, 0.32 s/batch, ets 2505.11s
# Epoch: 47
# Train Loss: 0.542170 Acc: 0.7163
# Elapsed 589.16s, 12.27 s/epoch, 0.32 s/batch, ets 2491.64s
# Epoch: 48
# Train Loss: 0.535951 Acc: 0.7220
# Elapsed 601.48s, 12.28 s/epoch, 0.32 s/batch, ets 2479.59s
# Epoch: 49
# Train Loss: 0.521504 Acc: 0.7278
# Elapsed 613.34s, 12.27 s/epoch, 0.32 s/batch, ets 2465.62s
# Epoch: 50
# Train Loss: 0.518720 Acc: 0.7303
# Elapsed 625.86s, 12.27 s/epoch, 0.32 s/batch, ets 2454.36s
#
# Test set: Average loss: 0.8487, Accuracy: 383/600 (64%)
#
# Epoch: 51
# Train Loss: 0.553379 Acc: 0.7196
# Elapsed 641.20s, 12.33 s/epoch, 0.32 s/batch, ets 2453.82s
# Epoch: 52
# Train Loss: 0.519170 Acc: 0.7397
# Elapsed 653.73s, 12.33 s/epoch, 0.32 s/batch, ets 2442.24s
# Epoch: 53
# Train Loss: 0.543150 Acc: 0.7266
# Elapsed 666.64s, 12.35 s/epoch, 0.32 s/batch, ets 2432.01s
# Epoch: 54
# Train Loss: 0.497954 Acc: 0.7278
# Elapsed 678.82s, 12.34 s/epoch, 0.32 s/batch, ets 2419.06s
# Epoch: 55
# Train Loss: 0.505133 Acc: 0.7512
# Elapsed 691.16s, 12.34 s/epoch, 0.32 s/batch, ets 2406.73s
# Epoch: 56
# Train Loss: 0.488315 Acc: 0.7438
# Elapsed 703.14s, 12.34 s/epoch, 0.32 s/batch, ets 2393.14s
# Epoch: 57
# Train Loss: 0.501773 Acc: 0.7471
# Elapsed 715.52s, 12.34 s/epoch, 0.32 s/batch, ets 2380.94s
# Epoch: 58
# Train Loss: 0.492255 Acc: 0.7590
# Elapsed 727.85s, 12.34 s/epoch, 0.32 s/batch, ets 2368.60s
# Epoch: 59
# Train Loss: 0.502961 Acc: 0.7377
# Elapsed 740.08s, 12.33 s/epoch, 0.32 s/batch, ets 2355.91s
# Epoch: 60
# Train Loss: 0.478310 Acc: 0.7664
# Elapsed 752.20s, 12.33 s/epoch, 0.32 s/batch, ets 2342.93s
#
# Test set: Average loss: 0.5801, Accuracy: 433/600 (72%)
#
# Model Improved. Saving the Model...
#
# Epoch: 61
# Train Loss: 0.522088 Acc: 0.7451
# Elapsed 768.00s, 12.39 s/epoch, 0.33 s/batch, ets 2341.17s
# Epoch: 62
# Train Loss: 0.470550 Acc: 0.7796
# Elapsed 780.37s, 12.39 s/epoch, 0.33 s/batch, ets 2328.71s
# Epoch: 63
# Train Loss: 0.475200 Acc: 0.7804
# Elapsed 792.93s, 12.39 s/epoch, 0.33 s/batch, ets 2316.84s
# Epoch: 64
# Train Loss: 0.484483 Acc: 0.7784
# Elapsed 805.15s, 12.39 s/epoch, 0.33 s/batch, ets 2303.97s
# Epoch: 65
# Train Loss: 0.485637 Acc: 0.7714
# Elapsed 817.93s, 12.39 s/epoch, 0.33 s/batch, ets 2292.69s
# Epoch: 66
# Train Loss: 0.499639 Acc: 0.7410
# Elapsed 830.60s, 12.40 s/epoch, 0.33 s/batch, ets 2281.05s
# Epoch: 67
# Train Loss: 0.487404 Acc: 0.7627
# Elapsed 842.57s, 12.39 s/epoch, 0.33 s/batch, ets 2267.49s
# Epoch: 68
# Train Loss: 0.515882 Acc: 0.7603
# Elapsed 855.43s, 12.40 s/epoch, 0.33 s/batch, ets 2256.35s
# Epoch: 69
# Train Loss: 0.488758 Acc: 0.7632
# Elapsed 867.20s, 12.39 s/epoch, 0.33 s/batch, ets 2242.33s
# Epoch: 70
# Train Loss: 0.477845 Acc: 0.7738
# Elapsed 879.12s, 12.38 s/epoch, 0.33 s/batch, ets 2228.76s
#
# Test set: Average loss: 0.7472, Accuracy: 405/600 (68%)
#
# Epoch: 71
# Train Loss: 0.478610 Acc: 0.7751
# Elapsed 894.41s, 12.42 s/epoch, 0.33 s/batch, ets 2223.60s
# Epoch: 72
# Train Loss: 0.466663 Acc: 0.7796
# Elapsed 906.56s, 12.42 s/epoch, 0.33 s/batch, ets 2210.53s
# Epoch: 73
# Train Loss: 0.428219 Acc: 0.7961
# Elapsed 919.10s, 12.42 s/epoch, 0.33 s/batch, ets 2198.40s
# Epoch: 74
# Train Loss: 0.477170 Acc: 0.7854
# Elapsed 930.82s, 12.41 s/epoch, 0.33 s/batch, ets 2184.33s
# Epoch: 75
# Train Loss: 0.444312 Acc: 0.7973
# Elapsed 942.66s, 12.40 s/epoch, 0.33 s/batch, ets 2170.60s
# Epoch: 76
# Train Loss: 0.444237 Acc: 0.8014
# Elapsed 955.24s, 12.41 s/epoch, 0.33 s/batch, ets 2158.59s
# Epoch: 77
# Train Loss: 0.432556 Acc: 0.7944
# Elapsed 967.45s, 12.40 s/epoch, 0.33 s/batch, ets 2145.75s
# Epoch: 78
# Train Loss: 0.431431 Acc: 0.8072
# Elapsed 980.21s, 12.41 s/epoch, 0.33 s/batch, ets 2134.13s
# Epoch: 79
# Train Loss: 0.409667 Acc: 0.8133
# Elapsed 992.20s, 12.40 s/epoch, 0.33 s/batch, ets 2120.83s
# Epoch: 80
# Train Loss: 0.472155 Acc: 0.7788
# Elapsed 1004.45s, 12.40 s/epoch, 0.33 s/batch, ets 2108.10s
#
# Test set: Average loss: 0.5610, Accuracy: 452/600 (75%)
#
# Model Improved. Saving the Model...
#
# Epoch: 81
# Train Loss: 0.445127 Acc: 0.8006
# Elapsed 1020.56s, 12.45 s/epoch, 0.33 s/batch, ets 2103.35s
# Epoch: 82
# Train Loss: 0.426584 Acc: 0.8067
# Elapsed 1032.68s, 12.44 s/epoch, 0.33 s/batch, ets 2090.24s
# Epoch: 83
# Train Loss: 0.404761 Acc: 0.8055
# Elapsed 1045.22s, 12.44 s/epoch, 0.33 s/batch, ets 2078.01s
# Epoch: 84
# Train Loss: 0.399548 Acc: 0.8162
# Elapsed 1057.52s, 12.44 s/epoch, 0.33 s/batch, ets 2065.28s
# Epoch: 85
# Train Loss: 0.449807 Acc: 0.7948
# Elapsed 1069.37s, 12.43 s/epoch, 0.33 s/batch, ets 2051.70s
# Epoch: 86
# Train Loss: 0.416064 Acc: 0.8220
# Elapsed 1081.99s, 12.44 s/epoch, 0.33 s/batch, ets 2039.62s
# Epoch: 87
# Train Loss: 0.406854 Acc: 0.8302
# Elapsed 1093.88s, 12.43 s/epoch, 0.33 s/batch, ets 2026.16s
# Epoch: 88
# Train Loss: 0.390353 Acc: 0.8314
# Elapsed 1105.99s, 12.43 s/epoch, 0.33 s/batch, ets 2013.15s
# Epoch: 89
# Train Loss: 0.399902 Acc: 0.8310
# Elapsed 1118.34s, 12.43 s/epoch, 0.33 s/batch, ets 2000.59s
# Epoch: 90
# Train Loss: 0.391231 Acc: 0.8248
# Elapsed 1130.66s, 12.42 s/epoch, 0.33 s/batch, ets 1987.97s
#
# Test set: Average loss: 0.4836, Accuracy: 473/600 (79%)
#
# Model Improved. Saving the Model...
#
# Epoch: 91
# Train Loss: 0.376804 Acc: 0.8376
# Elapsed 1146.51s, 12.46 s/epoch, 0.33 s/batch, ets 1981.48s
# Epoch: 92
# Train Loss: 0.366256 Acc: 0.8392
# Elapsed 1158.64s, 12.46 s/epoch, 0.33 s/batch, ets 1968.45s
# Epoch: 93
# Train Loss: 0.356646 Acc: 0.8446
# Elapsed 1171.09s, 12.46 s/epoch, 0.33 s/batch, ets 1955.97s
# Epoch: 94
# Train Loss: 0.387026 Acc: 0.8347
# Elapsed 1183.44s, 12.46 s/epoch, 0.33 s/batch, ets 1943.33s
# Epoch: 95
# Train Loss: 0.340091 Acc: 0.8532
# Elapsed 1195.62s, 12.45 s/epoch, 0.33 s/batch, ets 1930.43s
# Epoch: 96
# Train Loss: 0.347854 Acc: 0.8462
# Elapsed 1208.26s, 12.46 s/epoch, 0.33 s/batch, ets 1918.27s
# Epoch: 97
# Train Loss: 0.365562 Acc: 0.8507
# Elapsed 1220.74s, 12.46 s/epoch, 0.33 s/batch, ets 1905.84s
# Epoch: 98
# Train Loss: 0.365751 Acc: 0.8446
# Elapsed 1233.08s, 12.46 s/epoch, 0.33 s/batch, ets 1893.22s
# Epoch: 99
# Train Loss: 0.402972 Acc: 0.8277
# Elapsed 1245.78s, 12.46 s/epoch, 0.33 s/batch, ets 1881.13s
# Epoch: 100
# Train Loss: 0.340690 Acc: 0.8594
# Elapsed 1258.01s, 12.46 s/epoch, 0.33 s/batch, ets 1868.32s
#
# Test set: Average loss: 0.4895, Accuracy: 460/600 (77%)
#
# Epoch: 101
# Train Loss: 0.342043 Acc: 0.8581
# Elapsed 1273.16s, 12.48 s/epoch, 0.33 s/batch, ets 1859.81s
# Epoch: 102
# Train Loss: 0.333702 Acc: 0.8553
# Elapsed 1285.34s, 12.48 s/epoch, 0.33 s/batch, ets 1846.89s
# Epoch: 103
# Train Loss: 0.316832 Acc: 0.8692
# Elapsed 1297.24s, 12.47 s/epoch, 0.33 s/batch, ets 1833.60s
# Epoch: 104
# Train Loss: 0.304244 Acc: 0.8725
# Elapsed 1309.96s, 12.48 s/epoch, 0.33 s/batch, ets 1821.47s
# Epoch: 105
# Train Loss: 0.311488 Acc: 0.8840
# Elapsed 1321.76s, 12.47 s/epoch, 0.33 s/batch, ets 1808.07s
# Epoch: 106
# Train Loss: 0.342479 Acc: 0.8532
# Elapsed 1334.36s, 12.47 s/epoch, 0.33 s/batch, ets 1795.77s
# Epoch: 107
# Train Loss: 0.308865 Acc: 0.8721
# Elapsed 1346.18s, 12.46 s/epoch, 0.33 s/batch, ets 1782.44s
# Epoch: 108
# Train Loss: 0.312198 Acc: 0.8697
# Elapsed 1357.96s, 12.46 s/epoch, 0.33 s/batch, ets 1769.09s
# Epoch: 109
# Train Loss: 0.350240 Acc: 0.8614
# Elapsed 1370.38s, 12.46 s/epoch, 0.33 s/batch, ets 1756.58s
# Epoch: 110
# Train Loss: 0.296275 Acc: 0.8795
# Elapsed 1382.32s, 12.45 s/epoch, 0.33 s/batch, ets 1743.46s
#
# Test set: Average loss: 0.4899, Accuracy: 487/600 (81%)
#
# Epoch: 111
# Train Loss: 0.284342 Acc: 0.8762
# Elapsed 1397.51s, 12.48 s/epoch, 0.33 s/batch, ets 1734.41s
# Epoch: 112
# Train Loss: 0.336013 Acc: 0.8849
# Elapsed 1409.52s, 12.47 s/epoch, 0.33 s/batch, ets 1721.35s
# Epoch: 113
# Train Loss: 0.324470 Acc: 0.8787
# Elapsed 1421.47s, 12.47 s/epoch, 0.33 s/batch, ets 1708.26s
# Epoch: 114
# Train Loss: 0.309845 Acc: 0.8779
# Elapsed 1434.22s, 12.47 s/epoch, 0.33 s/batch, ets 1696.13s
# Epoch: 115
# Train Loss: 0.302631 Acc: 0.8758
# Elapsed 1446.13s, 12.47 s/epoch, 0.33 s/batch, ets 1682.99s
# Epoch: 116
# Train Loss: 0.300372 Acc: 0.8791
# Elapsed 1458.02s, 12.46 s/epoch, 0.33 s/batch, ets 1669.87s
# Epoch: 117
# Train Loss: 0.293254 Acc: 0.8836
# Elapsed 1470.38s, 12.46 s/epoch, 0.33 s/batch, ets 1657.29s
# Epoch: 118
# Train Loss: 0.293021 Acc: 0.8791
# Elapsed 1482.24s, 12.46 s/epoch, 0.33 s/batch, ets 1644.17s
# Epoch: 119
# Train Loss: 0.276234 Acc: 0.8845
# Elapsed 1494.72s, 12.46 s/epoch, 0.33 s/batch, ets 1631.73s
# Epoch: 120
# Train Loss: 0.300237 Acc: 0.8754
# Elapsed 1506.90s, 12.45 s/epoch, 0.33 s/batch, ets 1618.98s
#
# Test set: Average loss: 0.4360, Accuracy: 482/600 (80%)
#
# Model Improved. Saving the Model...
#
# Epoch: 121
# Train Loss: 0.276055 Acc: 0.8931
# Elapsed 1522.11s, 12.48 s/epoch, 0.33 s/batch, ets 1609.44s
# Epoch: 122
# Train Loss: 0.268127 Acc: 0.8947
# Elapsed 1534.33s, 12.47 s/epoch, 0.33 s/batch, ets 1596.71s
# Epoch: 123
# Train Loss: 0.254732 Acc: 0.8947
# Elapsed 1546.19s, 12.47 s/epoch, 0.33 s/batch, ets 1583.60s
# Epoch: 124
# Train Loss: 0.260942 Acc: 0.9017
# Elapsed 1558.48s, 12.47 s/epoch, 0.33 s/batch, ets 1570.95s
# Epoch: 125
# Train Loss: 0.271037 Acc: 0.8914
# Elapsed 1570.41s, 12.46 s/epoch, 0.33 s/batch, ets 1557.94s
# Epoch: 126
# Train Loss: 0.277719 Acc: 0.8919
# Elapsed 1582.30s, 12.46 s/epoch, 0.33 s/batch, ets 1544.92s
# Epoch: 127
# Train Loss: 0.225263 Acc: 0.9124
# Elapsed 1594.63s, 12.46 s/epoch, 0.33 s/batch, ets 1532.34s
# Epoch: 128
# Train Loss: 0.219817 Acc: 0.9223
# Elapsed 1606.51s, 12.45 s/epoch, 0.33 s/batch, ets 1519.33s
# Epoch: 129
# Train Loss: 0.233471 Acc: 0.9104
# Elapsed 1618.56s, 12.45 s/epoch, 0.33 s/batch, ets 1506.51s
# Epoch: 130
# Train Loss: 0.256371 Acc: 0.9100
# Elapsed 1630.86s, 12.45 s/epoch, 0.33 s/batch, ets 1493.92s
#
# Test set: Average loss: 0.4974, Accuracy: 498/600 (83%)
#
# Epoch: 131
# Train Loss: 0.219839 Acc: 0.9165
# Elapsed 1646.32s, 12.47 s/epoch, 0.33 s/batch, ets 1484.18s
# Epoch: 132
# Train Loss: 0.205401 Acc: 0.9223
# Elapsed 1658.74s, 12.47 s/epoch, 0.33 s/batch, ets 1471.67s
# Epoch: 133
# Train Loss: 0.222659 Acc: 0.9116
# Elapsed 1670.88s, 12.47 s/epoch, 0.33 s/batch, ets 1458.91s
# Epoch: 134
# Train Loss: 0.238502 Acc: 0.9100
# Elapsed 1682.66s, 12.46 s/epoch, 0.33 s/batch, ets 1445.84s
# Epoch: 135
# Train Loss: 0.219913 Acc: 0.9141
# Elapsed 1695.03s, 12.46 s/epoch, 0.33 s/batch, ets 1433.30s
# Epoch: 136
# Train Loss: 0.218882 Acc: 0.9231
# Elapsed 1707.07s, 12.46 s/epoch, 0.33 s/batch, ets 1420.49s
# Epoch: 137
# Train Loss: 0.225475 Acc: 0.9075
# Elapsed 1719.36s, 12.46 s/epoch, 0.33 s/batch, ets 1407.88s
# Epoch: 138
# Train Loss: 0.223821 Acc: 0.9206
# Elapsed 1731.61s, 12.46 s/epoch, 0.33 s/batch, ets 1395.25s
# Epoch: 139
# Train Loss: 0.215059 Acc: 0.9194
# Elapsed 1743.41s, 12.45 s/epoch, 0.33 s/batch, ets 1382.27s
# Epoch: 140
# Train Loss: 0.201445 Acc: 0.9149
# Elapsed 1755.60s, 12.45 s/epoch, 0.33 s/batch, ets 1369.62s
#
# Test set: Average loss: 0.9487, Accuracy: 437/600 (73%)
#
# Epoch: 141
# Train Loss: 0.205589 Acc: 0.9202
# Elapsed 1771.04s, 12.47 s/epoch, 0.33 s/batch, ets 1359.46s
# Epoch: 142
# Train Loss: 0.233213 Acc: 0.9157
# Elapsed 1783.45s, 12.47 s/epoch, 0.33 s/batch, ets 1346.94s
# Epoch: 143
# Train Loss: 0.243339 Acc: 0.9095
# Elapsed 1795.89s, 12.47 s/epoch, 0.33 s/batch, ets 1334.45s
# Epoch: 144
# Train Loss: 0.229951 Acc: 0.9112
# Elapsed 1808.63s, 12.47 s/epoch, 0.33 s/batch, ets 1322.17s
# Epoch: 145
# Train Loss: 0.206487 Acc: 0.9215
# Elapsed 1821.40s, 12.48 s/epoch, 0.33 s/batch, ets 1309.91s
# Epoch: 146
# Train Loss: 0.183619 Acc: 0.9309
# Elapsed 1833.67s, 12.47 s/epoch, 0.33 s/batch, ets 1297.29s
# Epoch: 147
# Train Loss: 0.229391 Acc: 0.9108
# Elapsed 1846.44s, 12.48 s/epoch, 0.33 s/batch, ets 1285.02s
# Epoch: 148
# Train Loss: 0.203621 Acc: 0.9252
# Elapsed 1858.66s, 12.47 s/epoch, 0.33 s/batch, ets 1272.37s
# Epoch: 149
# Train Loss: 0.185247 Acc: 0.9268
# Elapsed 1871.55s, 12.48 s/epoch, 0.33 s/batch, ets 1260.18s
# Epoch: 150
# Train Loss: 0.181338 Acc: 0.9350
# Elapsed 1884.22s, 12.48 s/epoch, 0.33 s/batch, ets 1247.83s
#
# Test set: Average loss: 0.7734, Accuracy: 457/600 (76%)
#
# Epoch: 151
# Train Loss: 0.189967 Acc: 0.9268
# Elapsed 1899.71s, 12.50 s/epoch, 0.33 s/batch, ets 1237.31s
# Epoch: 152
# Train Loss: 0.211202 Acc: 0.9227
# Elapsed 1912.12s, 12.50 s/epoch, 0.33 s/batch, ets 1224.76s
# Epoch: 153
# Train Loss: 0.159994 Acc: 0.9383
# Elapsed 1924.90s, 12.50 s/epoch, 0.33 s/batch, ets 1212.44s
# Epoch: 154
# Train Loss: 0.181360 Acc: 0.9338
# Elapsed 1937.23s, 12.50 s/epoch, 0.33 s/batch, ets 1199.83s
# Epoch: 155
# Train Loss: 0.197755 Acc: 0.9280
# Elapsed 1949.39s, 12.50 s/epoch, 0.33 s/batch, ets 1187.13s
# Epoch: 156
# Train Loss: 0.169247 Acc: 0.9338
# Elapsed 1961.63s, 12.49 s/epoch, 0.33 s/batch, ets 1174.48s
# Epoch: 157
# Train Loss: 0.177300 Acc: 0.9317
# Elapsed 1973.85s, 12.49 s/epoch, 0.33 s/batch, ets 1161.83s
# Epoch: 158
# Train Loss: 0.161375 Acc: 0.9338
# Elapsed 1986.25s, 12.49 s/epoch, 0.33 s/batch, ets 1149.27s
# Epoch: 159
# Train Loss: 0.201532 Acc: 0.9272
# Elapsed 1998.39s, 12.49 s/epoch, 0.33 s/batch, ets 1136.59s
# Epoch: 160
# Train Loss: 0.190987 Acc: 0.9260
# Elapsed 2010.76s, 12.49 s/epoch, 0.33 s/batch, ets 1124.03s
#
# Test set: Average loss: 0.4204, Accuracy: 517/600 (86%)
#
# Model Improved. Saving the Model...
#
# Epoch: 161
# Train Loss: 0.155914 Acc: 0.9416
# Elapsed 2026.31s, 12.51 s/epoch, 0.33 s/batch, ets 1113.22s
# Epoch: 162
# Train Loss: 0.156985 Acc: 0.9486
# Elapsed 2038.54s, 12.51 s/epoch, 0.33 s/batch, ets 1100.56s
# Epoch: 163
# Train Loss: 0.182589 Acc: 0.9317
# Elapsed 2051.46s, 12.51 s/epoch, 0.33 s/batch, ets 1088.28s
# Epoch: 164
# Train Loss: 0.190969 Acc: 0.9280
# Elapsed 2063.47s, 12.51 s/epoch, 0.33 s/batch, ets 1075.51s
# Epoch: 165
# Train Loss: 0.153155 Acc: 0.9482
# Elapsed 2076.22s, 12.51 s/epoch, 0.33 s/batch, ets 1063.13s
# Epoch: 166
# Train Loss: 0.218520 Acc: 0.9252
# Elapsed 2088.03s, 12.50 s/epoch, 0.33 s/batch, ets 1050.27s
# Epoch: 167
# Train Loss: 0.172742 Acc: 0.9317
# Elapsed 2100.19s, 12.50 s/epoch, 0.33 s/batch, ets 1037.59s
# Epoch: 168
# Train Loss: 0.183182 Acc: 0.9350
# Elapsed 2112.90s, 12.50 s/epoch, 0.33 s/batch, ets 1025.19s
# Epoch: 169
# Train Loss: 0.163453 Acc: 0.9465
# Elapsed 2125.32s, 12.50 s/epoch, 0.33 s/batch, ets 1012.65s
# Epoch: 170
# Train Loss: 0.189110 Acc: 0.9330
# Elapsed 2137.15s, 12.50 s/epoch, 0.33 s/batch, ets 999.84s
#
# Test set: Average loss: 0.5377, Accuracy: 480/600 (80%)
#
# Epoch: 171
# Train Loss: 0.176435 Acc: 0.9342
# Elapsed 2153.02s, 12.52 s/epoch, 0.33 s/batch, ets 988.89s
# Epoch: 172
# Train Loss: 0.141746 Acc: 0.9474
# Elapsed 2165.50s, 12.52 s/epoch, 0.33 s/batch, ets 976.35s
# Epoch: 173
# Train Loss: 0.173764 Acc: 0.9391
# Elapsed 2178.06s, 12.52 s/epoch, 0.33 s/batch, ets 963.85s
# Epoch: 174
# Train Loss: 0.162301 Acc: 0.9404
# Elapsed 2189.81s, 12.51 s/epoch, 0.33 s/batch, ets 951.00s
# Epoch: 175
# Train Loss: 0.143192 Acc: 0.9453
# Elapsed 2201.77s, 12.51 s/epoch, 0.33 s/batch, ets 938.25s
# Epoch: 176
# Train Loss: 0.154736 Acc: 0.9453
# Elapsed 2214.04s, 12.51 s/epoch, 0.33 s/batch, ets 925.65s
# Epoch: 177
# Train Loss: 0.141257 Acc: 0.9490
# Elapsed 2226.05s, 12.51 s/epoch, 0.33 s/batch, ets 912.93s
# Epoch: 178
# Train Loss: 0.155487 Acc: 0.9437
# Elapsed 2238.57s, 12.51 s/epoch, 0.33 s/batch, ets 900.43s
# Epoch: 179
# Train Loss: 0.140169 Acc: 0.9515
# Elapsed 2250.99s, 12.51 s/epoch, 0.33 s/batch, ets 887.89s
# Epoch: 180
# Train Loss: 0.138791 Acc: 0.9486
# Elapsed 2262.82s, 12.50 s/epoch, 0.33 s/batch, ets 875.12s
#
# Test set: Average loss: 0.4524, Accuracy: 508/600 (85%)
#
# Epoch: 181
# Train Loss: 0.139793 Acc: 0.9433
# Elapsed 2278.40s, 12.52 s/epoch, 0.33 s/batch, ets 863.79s
# Epoch: 182
# Train Loss: 0.134081 Acc: 0.9490
# Elapsed 2290.30s, 12.52 s/epoch, 0.33 s/batch, ets 851.04s
# Epoch: 183
# Train Loss: 0.112274 Acc: 0.9618
# Elapsed 2302.96s, 12.52 s/epoch, 0.33 s/batch, ets 838.58s
# Epoch: 184
# Train Loss: 0.170124 Acc: 0.9449
# Elapsed 2315.58s, 12.52 s/epoch, 0.33 s/batch, ets 826.10s
# Epoch: 185
# Train Loss: 0.143232 Acc: 0.9478
# Elapsed 2327.72s, 12.51 s/epoch, 0.33 s/batch, ets 813.45s
# Epoch: 186
# Train Loss: 0.144411 Acc: 0.9441
# Elapsed 2340.51s, 12.52 s/epoch, 0.33 s/batch, ets 801.03s
# Epoch: 187
# Train Loss: 0.152111 Acc: 0.9556
# Elapsed 2352.47s, 12.51 s/epoch, 0.33 s/batch, ets 788.33s
# Epoch: 188
# Train Loss: 0.185657 Acc: 0.9322
# Elapsed 2365.02s, 12.51 s/epoch, 0.33 s/batch, ets 775.83s
# Epoch: 189
# Train Loss: 0.144473 Acc: 0.9478
# Elapsed 2377.07s, 12.51 s/epoch, 0.33 s/batch, ets 763.16s
# Epoch: 190
# Train Loss: 0.125530 Acc: 0.9507
# Elapsed 2389.03s, 12.51 s/epoch, 0.33 s/batch, ets 750.48s
#
# Test set: Average loss: 0.5433, Accuracy: 500/600 (83%)
#
# Epoch: 191
# Train Loss: 0.283482 Acc: 0.9021
# Elapsed 2404.73s, 12.52 s/epoch, 0.33 s/batch, ets 738.95s
# Epoch: 192
# Train Loss: 0.181355 Acc: 0.9313
# Elapsed 2416.96s, 12.52 s/epoch, 0.33 s/batch, ets 726.34s
# Epoch: 193
# Train Loss: 0.120866 Acc: 0.9527
# Elapsed 2429.31s, 12.52 s/epoch, 0.33 s/batch, ets 713.77s
# Epoch: 194
# Train Loss: 0.129560 Acc: 0.9539
# Elapsed 2441.40s, 12.52 s/epoch, 0.33 s/batch, ets 701.12s
# Epoch: 195
# Train Loss: 0.131823 Acc: 0.9498
# Elapsed 2453.67s, 12.52 s/epoch, 0.33 s/batch, ets 688.53s
# Epoch: 196
# Train Loss: 0.129622 Acc: 0.9515
# Elapsed 2466.07s, 12.52 s/epoch, 0.33 s/batch, ets 675.98s
# Epoch: 197
# Train Loss: 0.128888 Acc: 0.9539
# Elapsed 2478.55s, 12.52 s/epoch, 0.33 s/batch, ets 663.45s
# Epoch: 198
# Train Loss: 0.131914 Acc: 0.9494
# Elapsed 2490.73s, 12.52 s/epoch, 0.33 s/batch, ets 650.84s
# Epoch: 199
# Train Loss: 0.141329 Acc: 0.9486
# Elapsed 2503.24s, 12.52 s/epoch, 0.33 s/batch, ets 638.33s
# Epoch: 200
# Train Loss: 0.107107 Acc: 0.9597
# Elapsed 2515.34s, 12.51 s/epoch, 0.33 s/batch, ets 625.71s
#
# Test set: Average loss: 0.5788, Accuracy: 500/600 (83%)
#
# Epoch: 201
# Train Loss: 0.131904 Acc: 0.9502
# Elapsed 2530.87s, 12.53 s/epoch, 0.33 s/batch, ets 613.92s
# Epoch: 202
# Train Loss: 0.108646 Acc: 0.9613
# Elapsed 2543.03s, 12.53 s/epoch, 0.33 s/batch, ets 601.31s
# Epoch: 203
# Train Loss: 0.101777 Acc: 0.9572
# Elapsed 2555.12s, 12.53 s/epoch, 0.33 s/batch, ets 588.68s
# Epoch: 204
# Train Loss: 0.141243 Acc: 0.9441
# Elapsed 2567.79s, 12.53 s/epoch, 0.33 s/batch, ets 576.19s
# Epoch: 205
# Train Loss: 0.109184 Acc: 0.9601
# Elapsed 2579.69s, 12.52 s/epoch, 0.33 s/batch, ets 563.53s
# Epoch: 206
# Train Loss: 0.109877 Acc: 0.9589
# Elapsed 2592.36s, 12.52 s/epoch, 0.33 s/batch, ets 551.03s
# Epoch: 207
# Train Loss: 0.115182 Acc: 0.9589
# Elapsed 2604.85s, 12.52 s/epoch, 0.33 s/batch, ets 538.50s
# Epoch: 208
# Train Loss: 0.110043 Acc: 0.9613
# Elapsed 2616.64s, 12.52 s/epoch, 0.33 s/batch, ets 525.83s
# Epoch: 209
# Train Loss: 0.127958 Acc: 0.9539
# Elapsed 2629.17s, 12.52 s/epoch, 0.33 s/batch, ets 513.31s
# Epoch: 210
# Train Loss: 0.115401 Acc: 0.9601
# Elapsed 2641.03s, 12.52 s/epoch, 0.33 s/batch, ets 500.67s
#
# Test set: Average loss: 0.4362, Accuracy: 513/600 (86%)
#
# Epoch: 211
# Train Loss: 0.094618 Acc: 0.9613
# Elapsed 2656.91s, 12.53 s/epoch, 0.33 s/batch, ets 488.77s
# Epoch: 212
# Train Loss: 0.105562 Acc: 0.9613
# Elapsed 2669.08s, 12.53 s/epoch, 0.33 s/batch, ets 476.17s
# Epoch: 213
# Train Loss: 0.122520 Acc: 0.9589
# Elapsed 2681.15s, 12.53 s/epoch, 0.33 s/batch, ets 463.56s
# Epoch: 214
# Train Loss: 0.112163 Acc: 0.9597
# Elapsed 2693.72s, 12.53 s/epoch, 0.33 s/batch, ets 451.04s
# Epoch: 215
# Train Loss: 0.090500 Acc: 0.9650
# Elapsed 2705.96s, 12.53 s/epoch, 0.33 s/batch, ets 438.47s
# Epoch: 216
# Train Loss: 0.107133 Acc: 0.9704
# Elapsed 2718.15s, 12.53 s/epoch, 0.33 s/batch, ets 425.89s
# Epoch: 217
# Train Loss: 0.112568 Acc: 0.9581
# Elapsed 2730.55s, 12.53 s/epoch, 0.33 s/batch, ets 413.34s
# Epoch: 218
# Train Loss: 0.087329 Acc: 0.9683
# Elapsed 2742.88s, 12.52 s/epoch, 0.33 s/batch, ets 400.79s
# Epoch: 219
# Train Loss: 0.088501 Acc: 0.9683
# Elapsed 2755.25s, 12.52 s/epoch, 0.33 s/batch, ets 388.24s
# Epoch: 220
# Train Loss: 0.106862 Acc: 0.9581
# Elapsed 2767.45s, 12.52 s/epoch, 0.33 s/batch, ets 375.67s
#
# Test set: Average loss: 0.5647, Accuracy: 520/600 (87%)
#
# Epoch: 221
# Train Loss: 0.085497 Acc: 0.9700
# Elapsed 2782.53s, 12.53 s/epoch, 0.33 s/batch, ets 363.48s
# Epoch: 222
# Train Loss: 0.096588 Acc: 0.9659
# Elapsed 2795.66s, 12.54 s/epoch, 0.33 s/batch, ets 351.02s
# Epoch: 223
# Train Loss: 0.103436 Acc: 0.9638
# Elapsed 2807.70s, 12.53 s/epoch, 0.33 s/batch, ets 338.43s
# Epoch: 224
# Train Loss: 0.081965 Acc: 0.9733
# Elapsed 2820.29s, 12.53 s/epoch, 0.33 s/batch, ets 325.90s
# Epoch: 225
# Train Loss: 0.108876 Acc: 0.9683
# Elapsed 2832.88s, 12.53 s/epoch, 0.33 s/batch, ets 313.37s
# Epoch: 226
# Train Loss: 0.091136 Acc: 0.9737
# Elapsed 2845.35s, 12.53 s/epoch, 0.33 s/batch, ets 300.83s
# Epoch: 227
# Train Loss: 0.116755 Acc: 0.9638
# Elapsed 2858.03s, 12.54 s/epoch, 0.33 s/batch, ets 288.31s
# Epoch: 228
# Train Loss: 0.118711 Acc: 0.9581
# Elapsed 2870.04s, 12.53 s/epoch, 0.33 s/batch, ets 275.72s
# Epoch: 229
# Train Loss: 0.096764 Acc: 0.9650
# Elapsed 2882.55s, 12.53 s/epoch, 0.33 s/batch, ets 263.19s
# Epoch: 230
# Train Loss: 0.102870 Acc: 0.9642
# Elapsed 2894.46s, 12.53 s/epoch, 0.33 s/batch, ets 250.60s
#
# Test set: Average loss: 0.5899, Accuracy: 490/600 (82%)
#
# Epoch: 231
# Train Loss: 0.098012 Acc: 0.9696
# Elapsed 2909.99s, 12.54 s/epoch, 0.33 s/batch, ets 238.32s
# Epoch: 232
# Train Loss: 0.097453 Acc: 0.9638
# Elapsed 2922.74s, 12.54 s/epoch, 0.33 s/batch, ets 225.79s
# Epoch: 233
# Train Loss: 0.147276 Acc: 0.9626
# Elapsed 2934.76s, 12.54 s/epoch, 0.33 s/batch, ets 213.21s
# Epoch: 234
# Train Loss: 0.141475 Acc: 0.9482
# Elapsed 2946.95s, 12.54 s/epoch, 0.33 s/batch, ets 200.64s
# Epoch: 235
# Train Loss: 0.189378 Acc: 0.9424
# Elapsed 2959.50s, 12.54 s/epoch, 0.33 s/batch, ets 188.10s
# Epoch: 236
# Train Loss: 0.110182 Acc: 0.9613
# Elapsed 2971.88s, 12.54 s/epoch, 0.33 s/batch, ets 175.55s
# Epoch: 237
# Train Loss: 0.104634 Acc: 0.9663
# Elapsed 2984.47s, 12.54 s/epoch, 0.33 s/batch, ets 163.02s
# Epoch: 238
# Train Loss: 0.105659 Acc: 0.9655
# Elapsed 2996.55s, 12.54 s/epoch, 0.33 s/batch, ets 150.45s
# Epoch: 239
# Train Loss: 0.074106 Acc: 0.9737
# Elapsed 3009.24s, 12.54 s/epoch, 0.33 s/batch, ets 137.92s
# Epoch: 240
# Train Loss: 0.104613 Acc: 0.9671
# Elapsed 3021.80s, 12.54 s/epoch, 0.33 s/batch, ets 125.39s
#
# Test set: Average loss: 0.4626, Accuracy: 503/600 (84%)
#
# Epoch: 241
# Train Loss: 0.073922 Acc: 0.9762
# Elapsed 3037.44s, 12.55 s/epoch, 0.33 s/batch, ets 112.96s
# Epoch: 242
# Train Loss: 0.079188 Acc: 0.9770
# Elapsed 3049.67s, 12.55 s/epoch, 0.33 s/batch, ets 100.40s
# Epoch: 243
# Train Loss: 0.089263 Acc: 0.9659
# Elapsed 3061.43s, 12.55 s/epoch, 0.33 s/batch, ets 87.83s
# Epoch: 244
# Train Loss: 0.097397 Acc: 0.9696
# Elapsed 3073.19s, 12.54 s/epoch, 0.33 s/batch, ets 75.26s
# Epoch: 245
# Train Loss: 0.085687 Acc: 0.9646
# Elapsed 3085.69s, 12.54 s/epoch, 0.33 s/batch, ets 62.72s
# Epoch: 246
# Train Loss: 0.097668 Acc: 0.9613
# Elapsed 3097.97s, 12.54 s/epoch, 0.33 s/batch, ets 50.17s
# Epoch: 247
# Train Loss: 0.083101 Acc: 0.9720
# Elapsed 3110.52s, 12.54 s/epoch, 0.33 s/batch, ets 37.63s
# Epoch: 248
# Train Loss: 0.096728 Acc: 0.9696
# Elapsed 3122.67s, 12.54 s/epoch, 0.33 s/batch, ets 25.08s
# Epoch: 249
# Train Loss: 0.082587 Acc: 0.9766
# Elapsed 3135.00s, 12.54 s/epoch, 0.33 s/batch, ets 12.54s
# Epoch: 250
# Train Loss: 0.100356 Acc: 0.9675
# Elapsed 3147.81s, 12.54 s/epoch, 0.33 s/batch, ets 0.00s
#
# Test set: Average loss: 0.5439, Accuracy: 504/600 (84%)
#
# Total time: 3151.01, Best Loss: 0.420

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss],
                   val_loss=[val_loss],
                   train_acc=[train_acc],
                   val_acc=[val_acc],
                   colors=['blue'],
                   loss_legend_loc='upper center',
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">Step 5. Sample Prediction</font><a name="step5"></a>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):

#     data = batch_input.to(device)
    data = batch_input.to("cpu")

    with torch.no_grad():
        output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]

    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]

    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get Predictions on a Batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2

    # It is important to do model.eval() before prediction
    model.eval()

    # Send model to cpu/cuda according to your system configuration
#     model.to(device)
    model.to("cpu")
    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))

    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())

    data_len = test_dataset.__len__()

    interval = int(data_len/batch_size)

    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)

        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)

    inputs = torch.stack(inputs)

    cls, prob = prediction(model, device, batch_input=inputs)

    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()


    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]],
                                                     prob[i],
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()

    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
train_config = TrainingConfiguration()
model_dir = train_config.model_dir
model_file_name = train_config.model_file_name

m = MyModel()
m, epoch = load_model(m, model_dir, model_file_name)

test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

get_sample_prediction(m, test_data_path, mean, std)
# Out:
# <ipython-input-44-2dcef1c69779>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path)
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# # <font style="color:red">Step 6. Display Confusion Matrix [10 Points]</font><a name="step6"></a>
#
# Display the confusion matrix for the above problem(Refer to the earlier lectures on Performance Metrics).
#
#
# The output should resemble this:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/02/c3_w5_sample_confusion_matrix.png' width=600>

# %%
# YOUR CODE HERE
def create_confusion_matrix(model, data_root, mean, std):
    batch_size = 200

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2

    # It is important to do model.eval() before prediction
    model.eval()

    # Send model to cpu/cuda according to your system configuration
#     model.to(device)
    model.to("cpu")

    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))

    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())

    data_len = test_dataset.__len__()
#     print("data_len", data_len)

    interval = int(data_len/batch_size)

    # imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        # img, _ = test_dataset.__getitem__(index)

        # imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)

    inputs = torch.stack(inputs)

    cls, prob = prediction(model, device, batch_input=inputs)

    cm = confusion_matrix(targets, cls)

    class_lables = ['cat', 'dog', 'panda']
    plt.figure()
    sns.heatmap(cm, annot=True, fmt='',
              xticklabels=class_lables, yticklabels=class_lables)

    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.show()

    return

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

train_config = TrainingConfiguration()
model_dir = train_config.model_dir
model_file_name = train_config.model_file_name

m = MyModel()
m, epoch = load_model(m, model_dir, model_file_name)


test_data_path = os.path.join(train_config.data_root, 'validation')
train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)

create_confusion_matrix(m, test_data_path, mean, std)
# Out:
# <ipython-input-44-2dcef1c69779>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path)
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2734, 0.2641, 0.2616])

# %% [markdown]
# Upon completing the assignment,  <font style="color:red">pload the 2 notebooks and the models folder on the portal for feedback.</font>
